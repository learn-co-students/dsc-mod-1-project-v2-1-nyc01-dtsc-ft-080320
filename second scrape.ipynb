# %%
import requests
import sys
import numpy as np
import time
import pandas as pd
from bs4 import BeautifulSoup
#time.sleep(1)

# %%
def get_links(year):
    """returns a list of link suffixes that connect to every movie in the
    boxofficemojo page for the given year"""
    page = requests.get("https://www.boxofficemojo.com/year/{}/".format(year))
    soup = BeautifulSoup(page.content, 'html.parser')
    if page.status_code >=400:
        return [page.status_code,"https://www.boxofficemojo.com/year/{}/".format(year)]
    links = soup.select(".a-text-left.mojo-field-type-release.mojo-cell-wide a")
    return links

# %%
def cash_str_to_int(string):
    #takes string containing a number with a symbol at the front and returns the int
    return int(string[1:].replace(",",""))

# %%
def make_movie_dict(links):
    """accepts a list of link suffixes and returns a dictionary that
    has a key for each link. The value of each item is also a dictionary
    containing keys
                    domestic, international, worldwide, budget, genres, and title,
    with types      float     float          float      float   list[strs]   str
    
    if an int is missing its replaced with none and if genres is missing it is
    replaced with an empty list
    """
    movie_dict = {}
    for link in links:
        time.sleep(np.random.random())
        current = requests.get("https://www.boxofficemojo.com" + link["href"])
        currysoup = BeautifulSoup(current.content, "html.parser")
        title = currysoup.find("h1").text
        print("scraping ", title)
        try:
            budget = cash_str_to_int(currysoup.find(text="Budget").next_element.text)
        except AttributeError:
            budget = None
        grossli = currysoup.select(".a-section.a-spacing-none.mojo-performance-summary-table .a-section.a-spacing-none")
        grosses = []
        for i in grossli:
            try:
                grosses.append(cash_str_to_int(i.select(".money")[0].text))
            except IndexError:
                grosses.append(None)
        try:
            genres = list(currysoup.select(".a-section.a-spacing-none.mojo-summary-values.mojo-hidden-from-mobile")[0])[6].find_all("span")[1].text.split()
        except IndexError:
            genres = []
        movie_dict[link["href"]] = {"domestic":grosses[0],
                                    "international":grosses[1],
                                    "worldwide":grosses[2],
                                    "budget":budget,
                                    "genres":genres,
                                    "title":title
                                   }
        print(movie_dict[link["href"]])
        #uncomment the below to see only one pull
        #return(movie_dict)
    return movie_dict

# %%
links_2020 = get_links(2020)
movie_dict_2020 = make_movie_dict(links_2020)
# Out:
# scraping  Bad Boys for Life
# {'domestic': 204417855, 'international': 220200000, 'worldwide': 424617855, 'budget': 90000000, 'genres': ['Action', 'Comedy', 'Crime', 'Thriller'], 'title': 'Bad Boys for Life'}
# scraping  1917
# {'domestic': 159227644, 'international': 221775855, 'worldwide': 381003499, 'budget': 95000000, 'genres': ['Drama', 'War'], 'title': '1917'}
# scraping  Sonic the Hedgehog
# {'domestic': 146066470, 'international': 160700000, 'worldwide': 306766470, 'budget': 85000000, 'genres': ['Action', 'Adventure', 'Comedy', 'Family', 'Sci-Fi'], 'title': 'Sonic the Hedgehog'}
# scraping  Jumanji: The Next Level
# {'domestic': 316831246, 'international': 479744747, 'worldwide': 796575993, 'budget': 125000000, 'genres': ['Action', 'Adventure', 'Comedy', 'Fantasy'], 'title': 'Jumanji: The Next Level'}
# scraping  Star Wars: The Rise of Skywalker
# {'domestic': 515202542, 'international': 558941706, 'worldwide': 1074144248, 'budget': 275000000, 'genres': ['Action', 'Adventure', 'Fantasy', 'Sci-Fi'], 'title': 'Star Wars: The Rise of Skywalker'}
# scraping  Harley Quinn: Birds of Prey
# {'domestic': 84158461, 'international': 117700000, 'worldwide': 201858461, 'budget': 84500000, 'genres': ['Action', 'Adventure', 'Crime'], 'title': 'Harley Quinn: Birds of Prey'}
# scraping  Dolittle
# {'domestic': 77047065, 'international': 166276165, 'worldwide': 243323230, 'budget': 175000000, 'genres': ['Adventure', 'Comedy', 'Family', 'Fantasy'], 'title': 'Dolittle'}
# scraping  Little Women
# {'domestic': 108101214, 'international': 101000000, 'worldwide': 209101214, 'budget': 40000000, 'genres': ['Drama', 'Romance'], 'title': 'Little Women'}
# scraping  The Invisible Man
# {'domestic': 64914050, 'international': 65646802, 'worldwide': 130560852, 'budget': 7000000, 'genres': ['Horror', 'Mystery', 'Sci-Fi', 'Thriller'], 'title': 'The Invisible Man'}
# scraping  The Call of the Wild
# {'domestic': 62342368, 'international': 45262258, 'worldwide': 107604626, 'budget': 135000000, 'genres': ['Adventure', 'Drama', 'Family'], 'title': 'The Call of the Wild'}
# scraping  Onward
# {'domestic': 61555145, 'international': 49690254, 'worldwide': 111245399, 'budget': None, 'genres': ['165', 'days/23', 'weeks'], 'title': 'Onward'}
# scraping  Knives Out
# {'domestic': 165363234, 'international': 143869563, 'worldwide': 309232797, 'budget': 40000000, 'genres': ['Comedy', 'Crime', 'Drama', 'Mystery', 'Thriller'], 'title': 'Knives Out'}
# scraping  Frozen II
# {'domestic': 477373578, 'international': 972653355, 'worldwide': 1450026933, 'budget': 150000000, 'genres': ['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy', 'Musical'], 'title': 'Frozen II'}
# scraping  Spies in Disguise
# {'domestic': 66757013, 'international': 104859751, 'worldwide': 171616764, 'budget': 100000000, 'genres': ['Action', 'Adventure', 'Animation', 'Comedy', 'Family', 'Sci-Fi'], 'title': 'Spies in Disguise'}
# scraping  The Gentlemen
# {'domestic': 36296853, 'international': 78700000, 'worldwide': 114996853, 'budget': 22000000, 'genres': ['Action', 'Comedy', 'Crime'], 'title': 'The Gentlemen'}
# scraping  Just Mercy
# {'domestic': 36001502, 'international': 14400000, 'worldwide': 50401502, 'budget': 25000000, 'genres': ['Biography', 'Crime', 'Drama'], 'title': 'Just Mercy'}
# scraping  Parasite
# {'domestic': 53369749, 'international': 203906443, 'worldwide': 257276192, 'budget': 11400000, 'genres': ['Comedy', 'Drama', 'Thriller'], 'title': 'Parasite'}
# scraping  Fantasy Island
# {'domestic': 26441782, 'international': 20874177, 'worldwide': 47315959, 'budget': 7000000, 'genres': ['Action', 'Adventure', 'Fantasy', 'Horror', 'Mystery', 'Thriller'], 'title': 'Fantasy Island'}
# scraping  Uncut Gems
# {'domestic': 50023780, 'international': None, 'worldwide': 50023780, 'budget': 19000000, 'genres': ['Crime', 'Drama', 'Thriller'], 'title': 'Uncut Gems'}
# scraping  Like a Boss
# {'domestic': 22169514, 'international': 7583629, 'worldwide': 29753143, 'budget': 29000000, 'genres': ['Comedy'], 'title': 'Like a Boss'}
# scraping  The Grudge
# {'domestic': 21221803, 'international': 28289516, 'worldwide': 49511319, 'budget': 10000000, 'genres': ['Horror', 'Mystery'], 'title': 'The Grudge'}
# scraping  The Photograph
# {'domestic': 20578185, 'international': 112594, 'worldwide': 20690779, 'budget': 16000000, 'genres': ['Drama', 'Romance'], 'title': 'The Photograph'}
# scraping  Underwater
# {'domestic': 17291078, 'international': 23591850, 'worldwide': 40882928, 'budget': None, 'genres': ['221', 'days/31', 'weeks'], 'title': 'Underwater'}
# scraping  The Turning
# {'domestic': 15472775, 'international': 3121577, 'worldwide': 18594352, 'budget': 14000000, 'genres': ['Drama', 'Horror', 'Mystery'], 'title': 'The Turning'}
# scraping  Gretel & Hansel
# {'domestic': 15347654, 'international': 6329211, 'worldwide': 21676865, 'budget': None, 'genres': ['200', 'days/28', 'weeks'], 'title': 'Gretel & Hansel'}
# scraping  My Hero Academia: Heroes Rising
# {'domestic': 13304000, 'international': 15883012, 'worldwide': 29187012, 'budget': None, 'genres': ['174', 'days/24', 'weeks'], 'title': 'My Hero Academia: Heroes Rising'}
# scraping  Bombshell
# {'domestic': 31762808, 'international': 28094738, 'worldwide': 59857546, 'budget': 32000000, 'genres': ['Biography', 'Drama'], 'title': 'Bombshell'}
# scraping  The Way Back
# {'domestic': 13590514, 'international': 1100000, 'worldwide': 14690514, 'budget': None, 'genres': ['165', 'days/23', 'weeks'], 'title': 'The Way Back'}
# scraping  Brahms: The Boy II
# {'domestic': 12611536, 'international': 7700000, 'worldwide': 20311536, 'budget': 10000000, 'genres': ['Drama', 'Horror', 'Mystery', 'Thriller'], 'title': 'Brahms: The Boy II'}
# scraping  Jojo Rabbit
# {'domestic': 33370906, 'international': 56964119, 'worldwide': 90335025, 'budget': 14000000, 'genres': ['Comedy', 'Drama', 'War'], 'title': 'Jojo Rabbit'}
# scraping  Impractical Jokers: The Movie
# {'domestic': 10691091, 'international': None, 'worldwide': 10691091, 'budget': 3000000, 'genres': ['Comedy'], 'title': 'Impractical Jokers: The Movie'}
# scraping  Ford v Ferrari
# {'domestic': 117624357, 'international': 107883853, 'worldwide': 225508210, 'budget': 97600000, 'genres': ['Action', 'Biography', 'Drama', 'Sport'], 'title': 'Ford v Ferrari'}
# scraping  Emma.
# {'domestic': 10055355, 'international': 15558509, 'worldwide': 25613864, 'budget': 10000000, 'genres': ['Comedy', 'Drama'], 'title': 'Emma.'}
# scraping  Bloodshot
# {'domestic': 10021787, 'international': 20829804, 'worldwide': 30851591, 'budget': 45000000, 'genres': ['Action', 'Drama', 'Sci-Fi'], 'title': 'Bloodshot'}
# scraping  I Still Believe
# {'domestic': 9868521, 'international': 3041018, 'worldwide': 12909539, 'budget': 12000000, 'genres': ['Biography', 'Drama', 'Music', 'Romance'], 'title': 'I Still Believe'}
# scraping  Downhill
# {'domestic': 8287061, 'international': 612134, 'worldwide': 8899195, 'budget': None, 'genres': ['186', 'days/26', 'weeks'], 'title': 'Downhill'}
# scraping  Weathering with You
# {'domestic': 7798743, 'international': 185378236, 'worldwide': 193176979, 'budget': None, 'genres': ['216', 'days/30', 'weeks'], 'title': 'Weathering with You'}
# scraping  Cats
# {'domestic': 27166770, 'international': 46577460, 'worldwide': 73744230, 'budget': 95000000, 'genres': ['Comedy', 'Drama', 'Family', 'Fantasy', 'Musical'], 'title': 'Cats'}
# scraping  The Hunt
# {'domestic': 5812500, 'international': 3611893, 'worldwide': 9424393, 'budget': 14000000, 'genres': ['Action', 'Horror', 'Thriller'], 'title': 'The Hunt'}
# scraping  The Rhythm Section
# {'domestic': 5437971, 'international': 551612, 'worldwide': 5989583, 'budget': 50000000, 'genres': ['Action', 'Drama', 'Mystery', 'Thriller'], 'title': 'The Rhythm Section'}
# scraping  A Beautiful Day in the Neighborhood
# {'domestic': 61704055, 'international': 6056822, 'worldwide': 67760877, 'budget': 25000000, 'genres': ['Biography', 'Drama'], 'title': 'A Beautiful Day in the Neighborhood'}
# scraping  Richard Jewell
# {'domestic': 22345542, 'international': 21400000, 'worldwide': 43745542, 'budget': 45000000, 'genres': ['Biography', 'Crime', 'Drama'], 'title': 'Richard Jewell'}
# scraping  Portrait of a Lady on Fire
# {'domestic': 3759854, 'international': 6159996, 'worldwide': 9919850, 'budget': None, 'genres': ['256', 'days/36', 'weeks'], 'title': 'Portrait of a Lady on Fire'}
# scraping  2020 Oscar Nominated Short Films
# {'domestic': 3306611, 'international': None, 'worldwide': 3306611, 'budget': None, 'genres': ['See', 'more', 'details', 'at', 'IMDbPro'], 'title': '2020 Oscar Nominated Short Films'}
# scraping  Queen & Slim
# {'domestic': 43808310, 'international': 3893946, 'worldwide': 47702256, 'budget': 18000000, 'genres': ['Crime', 'Drama', 'Romance'], 'title': 'Queen & Slim'}
# scraping  Las Pildoras De Mi Novio
# {'domestic': 2971116, 'international': 3321664, 'worldwide': 6292780, 'budget': None, 'genres': ['179', 'days/25', 'weeks'], 'title': 'Las Pildoras De Mi Novio'}
# scraping  The Last Full Measure
# {'domestic': 2949212, 'international': 415356, 'worldwide': 3364568, 'budget': None, 'genres': ['207', 'days/29', 'weeks'], 'title': 'The Last Full Measure'}
# scraping  Ip Man 4: The Finale
# {'domestic': 3956031, 'international': 172449312, 'worldwide': 176405343, 'budget': None, 'genres': ['125', 'theaters'], 'title': 'Ip Man 4: The Finale'}
# scraping  The Wretched
# {'domestic': 1806698, 'international': 1274704, 'worldwide': 3081402, 'budget': None, 'genres': ['101', 'theaters'], 'title': 'The Wretched'}
# scraping  The Lodge
# {'domestic': 2138907, 'international': 1013920, 'worldwide': 3152827, 'budget': None, 'genres': ['193', 'days/27', 'weeks'], 'title': 'The Lodge'}
# scraping  Joker
# {'domestic': 335451311, 'international': 738800000, 'worldwide': 1074251311, 'budget': 55000000, 'genres': ['Crime', 'Drama', 'Thriller'], 'title': 'Joker'}
# scraping  Once Upon a Time... In Hollywood
# {'domestic': 142502728, 'international': 231840898, 'worldwide': 374343626, 'budget': 90000000, 'genres': ['Comedy', 'Drama'], 'title': 'Once Upon a Time... In Hollywood'}
# scraping  The Rental
# {'domestic': 1372894, 'international': 330555, 'worldwide': 1703449, 'budget': None, 'genres': ['25', 'days/3', 'weeks'], 'title': 'The Rental'}
# scraping  Jurassic Park
# {'domestic': 1206600, 'international': 153333, 'worldwide': 1359933, 'budget': 63000000, 'genres': ['Action', 'Adventure', 'Sci-Fi', 'Thriller'], 'title': 'Jurassic Park'}
# scraping  The Assistant
# {'domestic': 1100313, 'international': 195777, 'worldwide': 1296090, 'budget': None, 'genres': ['200', 'days/28', 'weeks'], 'title': 'The Assistant'}
# scraping  Relic
# {'domestic': 1039375, 'international': 80424, 'worldwide': 1119799, 'budget': None, 'genres': ['46', 'days/6', 'weeks'], 'title': 'Relic'}
# scraping  Becky
# {'domestic': 1004574, 'international': 17910, 'worldwide': 1022484, 'budget': None, 'genres': ['74', 'days/10', 'weeks'], 'title': 'Becky'}
# scraping  The Song of Names
# {'domestic': 1077584, 'international': 61378, 'worldwide': 1138962, 'budget': None, 'genres': ['237', 'days/33', 'weeks'], 'title': 'The Song of Names'}
# scraping  Mafia Inc
# {'domestic': 889863, 'international': None, 'worldwide': 889863, 'budget': None, 'genres': ['85', 'theaters'], 'title': 'Mafia Inc'}
# scraping  The SpongeBob Movie: Sponge On The Run
# {'domestic': 865824, 'international': None, 'worldwide': 865824, 'budget': None, 'genres': ['4', 'days'], 'title': 'The SpongeBob Movie: Sponge On The Run'}
# scraping  Jay and Silent Bob Reboot
# {'domestic': 4589490, 'international': 101758, 'worldwide': 4691248, 'budget': None, 'genres': ['308', 'days/44', 'weeks'], 'title': 'Jay and Silent Bob Reboot'}
# scraping  A Hidden Life
# {'domestic': 1730597, 'international': 2870606, 'worldwide': 4601203, 'budget': None, 'genres': ['249', 'days/35', 'weeks'], 'title': 'A Hidden Life'}
# scraping  Sarileru Neekevvaru
# {'domestic': 821000, 'international': 545335, 'worldwide': 1366335, 'budget': None, 'genres': ['300', 'theaters'], 'title': 'Sarileru Neekevvaru'}
# scraping  21 Bridges
# {'domestic': 28539757, 'international': 21400000, 'worldwide': 49939757, 'budget': 33000000, 'genres': ['Action', 'Crime', 'Drama', 'Thriller'], 'title': '21 Bridges'}
# scraping  Star Wars: Episode V - The Empire Strikes Back
# {'domestic': 785000, 'international': 300278, 'worldwide': 1085278, 'budget': 18000000, 'genres': ['Action', 'Adventure', 'Fantasy', 'Sci-Fi'], 'title': 'Star Wars: Episode V - The Empire Strikes Back'}
# scraping  Jaws
# {'domestic': 758300, 'international': 67, 'worldwide': 758367, 'budget': 7000000, 'genres': ['60', 'days/8', 'weeks'], 'title': 'Jaws'}
# scraping  Baaghi 3
# {'domestic': 721439, 'international': 16001062, 'worldwide': 16722501, 'budget': None, 'genres': ['265', 'theaters'], 'title': 'Baaghi 3'}
# scraping  Patterns of Evidence: The Red Sea Miracle
# {'domestic': 696191, 'international': None, 'worldwide': 696191, 'budget': None, 'genres': ['See', 'more', 'details', 'at', 'IMDbPro'], 'title': 'Patterns of Evidence: The Red Sea Miracle'}
# scraping  Pain and Glory
# {'domestic': 4567338, 'international': 32569736, 'worldwide': 37137074, 'budget': None, 'genres': ['319', 'days/45', 'weeks'], 'title': 'Pain and Glory'}
# scraping  Merci pour tout
# {'domestic': 1073969, 'international': None, 'worldwide': 1073969, 'budget': None, 'genres': ['76', 'theaters'], 'title': 'Merci pour tout'}
# scraping  Maleficent: Mistress of Evil
# {'domestic': 113929605, 'international': 377800484, 'worldwide': 491730089, 'budget': 185000000, 'genres': ['Adventure', 'Family', 'Fantasy'], 'title': 'Maleficent: Mistress of Evil'}
# scraping  The Tax Collector
# {'domestic': 612528, 'international': None, 'worldwide': 612528, 'budget': None, 'genres': ['138', 'theaters'], 'title': 'The Tax Collector'}
# scraping  Ghostbusters
# {'domestic': 605000, 'international': 15883, 'worldwide': 620883, 'budget': 30000000, 'genres': ['46', 'days/6', 'weeks'], 'title': 'Ghostbusters'}
# scraping  Chhapaak
# {'domestic': 604334, 'international': 5927766, 'worldwide': 6532100, 'budget': None, 'genres': ['100', 'theaters'], 'title': 'Chhapaak'}
# scraping  Unhinged
# {'domestic': 601032, 'international': 3183336, 'worldwide': 3784368, 'budget': None, 'genres': ['4', 'days'], 'title': 'Unhinged'}
# scraping  Panga
# {'domestic': 582720, 'international': 4303404, 'worldwide': 4886124, 'budget': None, 'genres': ['102', 'theaters'], 'title': 'Panga'}
# scraping  Midway
# {'domestic': 56846802, 'international': 68802466, 'worldwide': 125649268, 'budget': 100000000, 'genres': ['Action', 'Adventure', 'Drama', 'History', 'War'], 'title': 'Midway'}
# scraping  The Goonies
# {'domestic': 565000, 'international': 351852, 'worldwide': 916852, 'budget': None, 'genres': ['145', 'theaters'], 'title': 'The Goonies'}
# scraping  Black Christmas
# {'domestic': 10429730, 'international': 8100000, 'worldwide': 18529730, 'budget': 5000000, 'genres': ['Horror', 'Mystery', 'Thriller'], 'title': 'Black Christmas'}
# scraping  Color Out of Space
# {'domestic': 765561, 'international': 257949, 'worldwide': 1023510, 'budget': None, 'genres': ['81', 'theaters'], 'title': 'Color Out of Space'}
# scraping  Followed
# {'domestic': 538179, 'international': None, 'worldwide': 538179, 'budget': None, 'genres': ['60', 'days/8', 'weeks'], 'title': 'Followed'}
# scraping  Harriet
# {'domestic': 43082155, 'international': 264862, 'worldwide': 43347017, 'budget': 17000000, 'genres': ['Action', 'Biography', 'Drama', 'History'], 'title': 'Harriet'}
# scraping  The Addams Family
# {'domestic': 100044905, 'international': 103000000, 'worldwide': 203044905, 'budget': 24000000, 'genres': ['Animation', 'Comedy', 'Family', 'Fantasy', 'Horror'], 'title': 'The Addams Family'}
# scraping  The Big Ugly
# {'domestic': 502388, 'international': 1292, 'worldwide': 503680, 'budget': None, 'genres': ['25', 'days/3', 'weeks'], 'title': 'The Big Ugly'}
# scraping  Dark Waters
# {'domestic': 11136084, 'international': 10489566, 'worldwide': 21625650, 'budget': None, 'genres': ['270', 'days/38', 'weeks'], 'title': 'Dark Waters'}
# scraping  Beauty and the Beast
# {'domestic': 467000, 'international': None, 'worldwide': 467000, 'budget': 160000000, 'genres': ['Family', 'Fantasy', 'Musical', 'Romance'], 'title': 'Beauty and the Beast'}
# scraping  Inside Out
# {'domestic': 460000, 'international': None, 'worldwide': 460000, 'budget': 175000000, 'genres': ['Adventure', 'Animation', 'Comedy', 'Drama', 'Family', 'Fantasy'], 'title': 'Inside Out'}
# scraping  Once Were Brothers: Robbie Robertson and the Band
# {'domestic': 449561, 'international': 4801, 'worldwide': 454362, 'budget': None, 'genres': ['179', 'days/25', 'weeks'], 'title': 'Once Were Brothers: Robbie Robertson and the Band'}
# scraping  Seberg
# {'domestic': 434702, 'international': 151143, 'worldwide': 585845, 'budget': None, 'genres': ['179', 'days/25', 'weeks'], 'title': 'Seberg'}
# scraping  Iron Man
# {'domestic': 430000, 'international': None, 'worldwide': 430000, 'budget': 140000000, 'genres': ['Action', 'Adventure', 'Sci-Fi'], 'title': 'Iron Man'}
# scraping  Fantastic Fungi
# {'domestic': 1788322, 'international': 89353, 'worldwide': 1877675, 'budget': None, 'genres': ['37', 'theaters'], 'title': 'Fantastic Fungi'}
# scraping  Infamous
# {'domestic': 429148, 'international': None, 'worldwide': 429148, 'budget': None, 'genres': ['58', 'theaters'], 'title': 'Infamous'}
# scraping  Black Panther
# {'domestic': 367000, 'international': 1463934, 'worldwide': 1830934, 'budget': None, 'genres': ['39', 'days/5', 'weeks'], 'title': 'Black Panther'}
# scraping  Greed
# {'domestic': 355308, 'international': 1103518, 'worldwide': 1458826, 'budget': None, 'genres': ['172', 'days/24', 'weeks'], 'title': 'Greed'}
# scraping  Ride Your Wave
# {'domestic': 332432, 'international': 3663453, 'worldwide': 3995885, 'budget': None, 'genres': ['605', 'theaters'], 'title': 'Ride Your Wave'}
# scraping  Les Misérables
# {'domestic': 330181, 'international': 18533012, 'worldwide': 18863193, 'budget': None, 'genres': ['221', 'days/31', 'weeks'], 'title': 'Les Misérables'}
# scraping  Clemency
# {'domestic': 364716, 'international': 236, 'worldwide': 364952, 'budget': None, 'genres': ['235', 'days/33', 'weeks'], 'title': 'Clemency'}
# scraping  Ordinary Love
# {'domestic': 323688, 'international': 412028, 'worldwide': 735716, 'budget': None, 'genres': ['186', 'days/26', 'weeks'], 'title': 'Ordinary Love'}
# scraping  Playing with Fire
# {'domestic': 44451847, 'international': 24179822, 'worldwide': 68631669, 'budget': 29900000, 'genres': ['Comedy', 'Family'], 'title': 'Playing with Fire'}
# scraping  Judy
# {'domestic': 24313888, 'international': 19346380, 'worldwide': 43660268, 'budget': None, 'genres': ['326', 'days/46', 'weeks'], 'title': 'Judy'}
# scraping  The Traitor
# {'domestic': 296027, 'international': 8484508, 'worldwide': 8780535, 'budget': None, 'genres': ['200', 'days/28', 'weeks'], 'title': 'The Traitor'}
# scraping  Gremlins
# {'domestic': 295000, 'international': None, 'worldwide': 295000, 'budget': None, 'genres': ['64', 'theaters'], 'title': 'Gremlins'}
# scraping  Mystify: Michael Hutchence
# {'domestic': 289573, 'international': 792883, 'worldwide': 1082456, 'budget': None, 'genres': ['See', 'more', 'details', 'at', 'IMDbPro'], 'title': 'Mystify: Michael Hutchence'}
# scraping  Created Equal: Clarence Thomas in His Own Words
# {'domestic': 282149, 'international': None, 'worldwide': 282149, 'budget': None, 'genres': ['200', 'days/28', 'weeks'], 'title': 'Created Equal: Clarence Thomas in His Own Words'}
# scraping  Peninsula
# {'domestic': 273292, 'international': 30470947, 'worldwide': 30744239, 'budget': None, 'genres': ['48', 'theaters'], 'title': 'Peninsula'}
# scraping  An American in Paris
# {'domestic': 267824, 'international': None, 'worldwide': 267824, 'budget': None, 'genres': ['651', 'theaters'], 'title': 'An American in Paris'}
# scraping  Bohemian Rhapsody
# {'domestic': 240000, 'international': 32597107, 'worldwide': 32837107, 'budget': 52000000, 'genres': ['Biography', 'Drama', 'Music'], 'title': 'Bohemian Rhapsody'}
# scraping  63 Up
# {'domestic': 483684, 'international': None, 'worldwide': 483684, 'budget': None, 'genres': ['28', 'theaters'], 'title': '63 Up'}
# scraping  Tokyo Godfathers
# {'domestic': 237571, 'international': None, 'worldwide': 237571, 'budget': None, 'genres': ['162', 'days/23', 'weeks'], 'title': 'Tokyo Godfathers'}
# scraping  Blind Eyes Opened
# {'domestic': 234505, 'international': None, 'worldwide': 234505, 'budget': None, 'genres': ['See', 'more', 'details', 'at', 'IMDbPro'], 'title': 'Blind Eyes Opened'}
# scraping  Doctor Who Live Q&A And Screening
# {'domestic': 228615, 'international': None, 'worldwide': 228615, 'budget': None, 'genres': ['See', 'more', 'details', 'at', 'IMDbPro'], 'title': 'Doctor Who Live Q&A And Screening'}
# scraping  CatVideoFest 2020
# {'domestic': 437625, 'international': None, 'worldwide': 437625, 'budget': None, 'genres': ['84', 'theaters'], 'title': 'CatVideoFest 2020'}
# scraping  Ashfall
# {'domestic': 372562, 'international': 60883393, 'worldwide': 61255955, 'budget': None, 'genres': ['18', 'theaters'], 'title': 'Ashfall'}
# scraping  National Theater Live: Cyrano de Bergerac
# {'domestic': 198352, 'international': 1166851, 'worldwide': 1365203, 'budget': None, 'genres': ['See', 'more', 'details', 'at', 'IMDbPro'], 'title': 'National Theater Live: Cyrano de Bergerac'}
# scraping  Zombieland: Double Tap
# {'domestic': 73123082, 'international': 49687317, 'worldwide': 122810399, 'budget': 42000000, 'genres': ['Action', 'Adventure', 'Comedy', 'Horror'], 'title': 'Zombieland: Double Tap'}
# scraping  Cunningham
# {'domestic': 265102, 'international': 55191, 'worldwide': 320293, 'budget': None, 'genres': ['249', 'days/35', 'weeks'], 'title': 'Cunningham'}
# scraping  The Doors: Break On Thru - A Celebration Of Ray Manzarek
# {'domestic': 190160, 'international': None, 'worldwide': 190160, 'budget': None, 'genres': ['330', 'theaters'], 'title': 'The Doors: Break On Thru - A Celebration Of Ray Manzarek'}
# scraping  The Good Liar
# {'domestic': 17156058, 'international': 16700000, 'worldwide': 33856058, 'budget': 10000000, 'genres': ['Crime', 'Drama', 'Mystery', 'Thriller'], 'title': 'The Good Liar'}
# scraping  And Then We Danced
# {'domestic': 177262, 'international': 402312, 'worldwide': 579574, 'budget': None, 'genres': ['23', 'theaters'], 'title': 'And Then We Danced'}
# scraping  Beanpole
# {'domestic': 196258, 'international': 1391393, 'worldwide': 1587651, 'budget': None, 'genres': ['35', 'theaters'], 'title': 'Beanpole'}
# scraping  Extra Ordinary
# {'domestic': 164346, 'international': 59552, 'worldwide': 223898, 'budget': None, 'genres': ['165', 'days/23', 'weeks'], 'title': 'Extra Ordinary'}
# scraping  Palm Springs
# {'domestic': 164000, 'international': None, 'worldwide': 164000, 'budget': None, 'genres': ['39', 'days/5', 'weeks'], 'title': 'Palm Springs'}
# scraping  Love Story
# {'domestic': 153504, 'international': None, 'worldwide': 153504, 'budget': None, 'genres': ['191', 'days/27', 'weeks'], 'title': 'Love Story'}
# scraping  Wendy
# {'domestic': 143518, 'international': 1046, 'worldwide': 144564, 'budget': 6000000, 'genres': ['Drama', 'Fantasy'], 'title': 'Wendy'}
# scraping  Incitement
# {'domestic': 140306, 'international': None, 'worldwide': 140306, 'budget': None, 'genres': ['21', 'theaters'], 'title': 'Incitement'}
# scraping  Archive
# {'domestic': 139593, 'international': None, 'worldwide': 139593, 'budget': None, 'genres': ['26', 'theaters'], 'title': 'Archive'}
# scraping  Burden
# {'domestic': 139270, 'international': 188568, 'worldwide': 327838, 'budget': None, 'genres': ['172', 'days/24', 'weeks'], 'title': 'Burden'}
# scraping  Most Wanted
# {'domestic': 138000, 'international': None, 'worldwide': 138000, 'budget': None, 'genres': ['72', 'theaters'], 'title': 'Most Wanted'}
# scraping  Beneath Us
# {'domestic': 137260, 'international': None, 'worldwide': 137260, 'budget': None, 'genres': ['165', 'days/23', 'weeks'], 'title': 'Beneath Us'}
# scraping  The Times of Bill Cunningham
# {'domestic': 134288, 'international': None, 'worldwide': 134288, 'budget': None, 'genres': ['19', 'theaters'], 'title': 'The Times of Bill Cunningham'}
# scraping  No Safe Spaces
# {'domestic': 1291514, 'international': None, 'worldwide': 1291514, 'budget': None, 'genres': ['298', 'days/42', 'weeks'], 'title': 'No Safe Spaces'}
# scraping  14 Days, 12 Nights
# {'domestic': 122530, 'international': 276, 'worldwide': 122806, 'budget': None, 'genres': ['19', 'theaters'], 'title': '14 Days, 12 Nights'}
# scraping  Invisible Life
# {'domestic': 146535, 'international': 1619714, 'worldwide': 1766249, 'budget': None, 'genres': ['242', 'days/34', 'weeks'], 'title': 'Invisible Life'}
# scraping  The Man Standing Next
# {'domestic': 113527, 'international': 34551373, 'worldwide': 34664900, 'budget': None, 'genres': ['22', 'theaters'], 'title': 'The Man Standing Next'}
# scraping  Corpus Christi
# {'domestic': 127240, 'international': 8538107, 'worldwide': 8665347, 'budget': None, 'genres': ['23', 'theaters'], 'title': 'Corpus Christi'}
# scraping  Back to the Future
# {'domestic': 107000, 'international': 137635, 'worldwide': 244635, 'budget': 19000000, 'genres': ['18', 'days/2', 'weeks'], 'title': 'Back to the Future'}
# scraping  Hope Gap
# {'domestic': 104732, 'international': 19679, 'worldwide': 124411, 'budget': None, 'genres': ['165', 'days/23', 'weeks'], 'title': 'Hope Gap'}
# scraping  Citizen K
# {'domestic': 120411, 'international': 25530, 'worldwide': 145941, 'budget': None, 'genres': ['15', 'theaters'], 'title': 'Citizen K'}
# scraping  Grease
# {'domestic': 102000, 'international': 36981, 'worldwide': 138981, 'budget': 6000000, 'genres': ['Musical', 'Romance'], 'title': 'Grease'}
# scraping  First Cow
# {'domestic': 101068, 'international': None, 'worldwide': 101068, 'budget': None, 'genres': ['165', 'days/23', 'weeks'], 'title': 'First Cow'}
# scraping  The Woman Who Loves Giraffes
# {'domestic': 113858, 'international': None, 'worldwide': 113858, 'budget': None, 'genres': ['22', 'theaters'], 'title': 'The Woman Who Loves Giraffes'}
# scraping  Come to Daddy
# {'domestic': 96713, 'international': 20217, 'worldwide': 116930, 'budget': None, 'genres': ['193', 'days/27', 'weeks'], 'title': 'Come to Daddy'}
# scraping  The Wandering Earth
# {'domestic': 5971413, 'international': 693885286, 'worldwide': 699856699, 'budget': None, 'genres': ['129', 'theaters'], 'title': 'The Wandering Earth'}
# scraping  The Lighthouse
# {'domestic': 10867104, 'international': 7238090, 'worldwide': 18105194, 'budget': None, 'genres': ['305', 'days/43', 'weeks'], 'title': 'The Lighthouse'}
# scraping  The Burnt Orange Heresy
# {'domestic': 94410, 'international': 283929, 'worldwide': 378339, 'budget': None, 'genres': ['165', 'days/23', 'weeks'], 'title': 'The Burnt Orange Heresy'}
# scraping  First Lady
# {'domestic': 93298, 'international': None, 'worldwide': 93298, 'budget': None, 'genres': ['186', 'days/26', 'weeks'], 'title': 'First Lady'}
# scraping  Miss Juneteenth
# {'domestic': 92349, 'international': None, 'worldwide': 92349, 'budget': None, 'genres': ['11', 'theaters'], 'title': 'Miss Juneteenth'}
# scraping  Honeyland
# {'domestic': 815082, 'international': 358185, 'worldwide': 1173267, 'budget': None, 'genres': ['56', 'theaters'], 'title': 'Honeyland'}
# scraping  Riverdance 25th Anniversary Show
# {'domestic': 81879, 'international': 837853, 'worldwide': 919732, 'budget': None, 'genres': ['278', 'theaters'], 'title': 'Riverdance 25th Anniversary Show'}
# scraping  StarDog and TurboCat
# {'domestic': 80490, 'international': 358772, 'worldwide': 439262, 'budget': None, 'genres': ['60', 'days/8', 'weeks'], 'title': 'StarDog and TurboCat'}
# scraping  Made in Italy
# {'domestic': 73012, 'international': 167553, 'worldwide': 240565, 'budget': None, 'genres': ['11', 'days/1', 'week'], 'title': 'Made in Italy'}
# scraping  Honey Boy
# {'domestic': 3012615, 'international': 388362, 'worldwide': 3400977, 'budget': None, 'genres': ['284', 'days/40', 'weeks'], 'title': 'Honey Boy'}
# scraping  Come and See
# {'domestic': 71909, 'international': None, 'worldwide': 71909, 'budget': None, 'genres': ['3', 'theaters'], 'title': 'Come and See'}
# scraping  How to Build a Girl
# {'domestic': 70632, 'international': None, 'worldwide': 70632, 'budget': None, 'genres': ['102', 'days/14', 'weeks'], 'title': 'How to Build a Girl'}
# scraping  Chal Mera Putt 2
# {'domestic': 445000, 'international': 625997, 'worldwide': 1070997, 'budget': None, 'genres': [], 'title': 'Chal Mera Putt 2'}
# scraping  Waves
# {'domestic': 1658790, 'international': 864525, 'worldwide': 2523315, 'budget': None, 'genres': ['277', 'days/39', 'weeks'], 'title': 'Waves'}
# scraping  We Summon the Darkness
# {'domestic': 60794, 'international': 79311, 'worldwide': 140105, 'budget': None, 'genres': ['10', 'theaters'], 'title': 'We Summon the Darkness'}
# scraping  Varda by Agnès
# {'domestic': 160765, 'international': 74570, 'worldwide': 235335, 'budget': None, 'genres': ['10', 'theaters'], 'title': 'Varda by Agnès'}
# scraping  The Whistlers
# {'domestic': 55608, 'international': 753135, 'worldwide': 808743, 'budget': None, 'genres': ['8', 'theaters'], 'title': 'The Whistlers'}
# scraping  A Simple Wedding
# {'domestic': 54415, 'international': None, 'worldwide': 54415, 'budget': None, 'genres': ['10', 'theaters'], 'title': 'A Simple Wedding'}
# scraping  Summerland
# {'domestic': 52822, 'international': 60713, 'worldwide': 113535, 'budget': None, 'genres': ['18', 'days/2', 'weeks'], 'title': 'Summerland'}
# scraping  Miss Fisher and the Crypt of Tears
# {'domestic': 51032, 'international': 126, 'worldwide': 51158, 'budget': None, 'genres': ['18', 'theaters'], 'title': 'Miss Fisher and the Crypt of Tears'}
# scraping  The Wonderland
# {'domestic': 50876, 'international': 540981, 'worldwide': 591857, 'budget': None, 'genres': ['143', 'theaters'], 'title': 'The Wonderland'}
# scraping  VHYes
# {'domestic': 47037, 'international': None, 'worldwide': 47037, 'budget': None, 'genres': ['See', 'more', 'details', 'at', 'IMDbPro'], 'title': 'VHYes'}
# scraping  Charlie's Angels
# {'domestic': 17803077, 'international': 55476811, 'worldwide': 73279888, 'budget': 48000000, 'genres': ['Action', 'Adventure', 'Comedy'], 'title': "Charlie's Angels"}
# scraping  Enter the Fat Dragon
# {'domestic': 46855, 'international': None, 'worldwide': 46855, 'budget': None, 'genres': ['11', 'theaters'], 'title': 'Enter the Fat Dragon'}
# scraping  Saint Frances
# {'domestic': 44330, 'international': 14927, 'worldwide': 59257, 'budget': None, 'genres': ['23', 'theaters'], 'title': 'Saint Frances'}
# scraping  Doctor Sleep
# {'domestic': 31581712, 'international': 40800000, 'worldwide': 72381712, 'budget': 45000000, 'genres': ['Drama', 'Fantasy', 'Horror', 'Thriller'], 'title': 'Doctor Sleep'}
# scraping  The White Sheik
# {'domestic': 50850, 'international': 18090, 'worldwide': 68940, 'budget': None, 'genres': ['3', 'theaters'], 'title': 'The White Sheik'}
# scraping  Abominable
# {'domestic': 60716390, 'international': 120088003, 'worldwide': 180804393, 'budget': 75000000, 'genres': ['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy'], 'title': 'Abominable'}
# scraping  Three Christs
# {'domestic': 36723, 'international': None, 'worldwide': 36723, 'budget': None, 'genres': ['31', 'theaters'], 'title': 'Three Christs'}
# scraping  Last Christmas
# {'domestic': 35150750, 'international': 86400000, 'worldwide': 121550750, 'budget': 25000000, 'genres': ['Comedy', 'Drama', 'Romance'], 'title': 'Last Christmas'}
# scraping  Play the Flute
# {'domestic': 241856, 'international': None, 'worldwide': 241856, 'budget': None, 'genres': ['See', 'more', 'details', 'at', 'IMDbPro'], 'title': 'Play the Flute'}
# scraping  True History of the Kelly Gang
# {'domestic': 33817, 'international': 433381, 'worldwide': 467198, 'budget': None, 'genres': ['116', 'days/16', 'weeks'], 'title': 'True History of the Kelly Gang'}
# scraping  Swallow
# {'domestic': 33419, 'international': 240840, 'worldwide': 274259, 'budget': None, 'genres': ['165', 'days/23', 'weeks'], 'title': 'Swallow'}
# scraping  Nick Mason's Saucerful of Secrets: Live at the Roundhouse
# {'domestic': 32444, 'international': 37523, 'worldwide': 69967, 'budget': None, 'genres': [], 'title': "Nick Mason's Saucerful of Secrets: Live at the Roundhouse"}
# scraping  Max Winslow and the House of Secrets
# {'domestic': 31250, 'international': None, 'worldwide': 31250, 'budget': None, 'genres': ['81', 'days/11', 'weeks'], 'title': 'Max Winslow and the House of Secrets'}
# scraping  After Parkland
# {'domestic': 30444, 'international': None, 'worldwide': 30444, 'budget': None, 'genres': ['See', 'more', 'details', 'at', 'IMDbPro'], 'title': 'After Parkland'}
# scraping  Juvenile Delinquents
# {'domestic': 29502, 'international': 5163, 'worldwide': 34665, 'budget': None, 'genres': ['165', 'days/23', 'weeks'], 'title': 'Juvenile Delinquents'}
# scraping  Olympic Dreams
# {'domestic': 29450, 'international': None, 'worldwide': 29450, 'budget': None, 'genres': ['186', 'days/26', 'weeks'], 'title': 'Olympic Dreams'}
# scraping  Buffaloed
# {'domestic': 29118, 'international': None, 'worldwide': 29118, 'budget': None, 'genres': ['9', 'theaters'], 'title': 'Buffaloed'}
# scraping  Bacurau
# {'domestic': 58115, 'international': 3479172, 'worldwide': 3537287, 'budget': None, 'genres': ['6', 'theaters'], 'title': 'Bacurau'}
# scraping  Countdown
# {'domestic': 25621766, 'international': 22400000, 'worldwide': 48021766, 'budget': 6500000, 'genres': ['Horror', 'Thriller'], 'title': 'Countdown'}
# scraping  Cane River
# {'domestic': 27317, 'international': None, 'worldwide': 27317, 'budget': None, 'genres': ['See', 'more', 'details', 'at', 'IMDbPro'], 'title': 'Cane River'}
# scraping  Midnight Family
# {'domestic': 42310, 'international': 9402, 'worldwide': 51712, 'budget': None, 'genres': ['13', 'theaters'], 'title': 'Midnight Family'}
# scraping  José
# {'domestic': 26563, 'international': None, 'worldwide': 26563, 'budget': None, 'genres': ['2', 'theaters'], 'title': 'José'}
# scraping  Synonyms
# {'domestic': 206003, 'international': 295220, 'worldwide': 501223, 'budget': None, 'genres': ['13', 'theaters'], 'title': 'Synonyms'}
# scraping  The Booksellers
# {'domestic': 25694, 'international': 127766, 'worldwide': 153460, 'budget': None, 'genres': ['3', 'theaters'], 'title': 'The Booksellers'}
# scraping  Promare
# {'domestic': 2313596, 'international': 7151775, 'worldwide': 9465371, 'budget': None, 'genres': ['336', 'days/48', 'weeks'], 'title': 'Promare'}
# scraping  Unsubscribe
# {'domestic': 25488, 'international': None, 'worldwide': 25488, 'budget': None, 'genres': ['See', 'more', 'details', 'at', 'IMDbPro'], 'title': 'Unsubscribe'}
# scraping  Disappearance at Clifton Hill
# {'domestic': 25084, 'international': None, 'worldwide': 25084, 'budget': None, 'genres': ['19', 'theaters'], 'title': 'Disappearance at Clifton Hill'}
# scraping  Zombi Child
# {'domestic': 25878, 'international': 175031, 'worldwide': 200909, 'budget': None, 'genres': ['9', 'theaters'], 'title': 'Zombi Child'}
# scraping  Heart of Africa
# {'domestic': 24139, 'international': None, 'worldwide': 24139, 'budget': None, 'genres': ['20', 'theaters'], 'title': 'Heart of Africa'}
# scraping  Born to Be Wild
# {'domestic': 25978556, 'international': 15665919, 'worldwide': 41644475, 'budget': None, 'genres': ['208', 'theaters'], 'title': 'Born to Be Wild'}
# scraping  Tread
# {'domestic': 36527, 'international': None, 'worldwide': 36527, 'budget': None, 'genres': ['25', 'theaters'], 'title': 'Tread'}
# scraping  Branagh Theatre Live: The Winter's Tale
# {'domestic': 141143, 'international': None, 'worldwide': 141143, 'budget': None, 'genres': ['106', 'theaters'], 'title': "Branagh Theatre Live: The Winter's Tale"}
# scraping  Phoenix, Oregon
# {'domestic': 23613, 'international': None, 'worldwide': 23613, 'budget': None, 'genres': ['151', 'days/21', 'weeks'], 'title': 'Phoenix, Oregon'}
# scraping  Premature
# {'domestic': 23071, 'international': None, 'worldwide': 23071, 'budget': None, 'genres': ['29', 'theaters'], 'title': 'Premature'}
# scraping  L'Innocente
# {'domestic': 22549, 'international': None, 'worldwide': 22549, 'budget': None, 'genres': ['2', 'theaters'], 'title': "L'Innocente"}
# scraping  Recorder: The Marion Stokes Project
# {'domestic': 55632, 'international': None, 'worldwide': 55632, 'budget': None, 'genres': ['5', 'theaters'], 'title': 'Recorder: The Marion Stokes Project'}
# scraping  Les Misérables: The Staged Concert
# {'domestic': 459478, 'international': 4797953, 'worldwide': 5257431, 'budget': None, 'genres': ['488', 'theaters'], 'title': 'Les Misérables: The Staged Concert'}
# scraping  The Cordillera of Dreams
# {'domestic': 20943, 'international': 119522, 'worldwide': 140465, 'budget': None, 'genres': ['8', 'theaters'], 'title': 'The Cordillera of Dreams'}
# scraping  Spree
# {'domestic': 20480, 'international': None, 'worldwide': 20480, 'budget': None, 'genres': ['33', 'theaters'], 'title': 'Spree'}
# scraping  Lore
# {'domestic': 20006, 'international': None, 'worldwide': 20006, 'budget': None, 'genres': ['7', 'theaters'], 'title': 'Lore'}
# scraping  The Jesus Rolls
# {'domestic': 18169, 'international': 46479, 'worldwide': 64648, 'budget': None, 'genres': ['4', 'theaters'], 'title': 'The Jesus Rolls'}
# scraping  Sorry We Missed You
# {'domestic': 28273, 'international': 8737876, 'worldwide': 8766149, 'budget': None, 'genres': ['6', 'theaters'], 'title': 'Sorry We Missed You'}
# scraping  Downtown 81
# {'domestic': 122390, 'international': None, 'worldwide': 122390, 'budget': None, 'genres': ['8', 'theaters'], 'title': 'Downtown 81'}
# scraping  Pandora and the Flying Dutchman
# {'domestic': 17401, 'international': None, 'worldwide': 17401, 'budget': None, 'genres': ['2', 'theaters'], 'title': 'Pandora and the Flying Dutchman'}
# scraping  Made in Hong Kong
# {'domestic': 17255, 'international': None, 'worldwide': 17255, 'budget': None, 'genres': ['1', 'theater'], 'title': 'Made in Hong Kong'}
# scraping  Never Rarely Sometimes Always
# {'domestic': 16565, 'international': 72151, 'worldwide': 88716, 'budget': None, 'genres': ['158', 'days/22', 'weeks'], 'title': 'Never Rarely Sometimes Always'}
# scraping  Advocate
# {'domestic': 16942, 'international': None, 'worldwide': 16942, 'budget': None, 'genres': ['2', 'theaters'], 'title': 'Advocate'}
# scraping  American Deep State
# {'domestic': 15269, 'international': None, 'worldwide': 15269, 'budget': None, 'genres': ['4', 'days'], 'title': 'American Deep State'}
# scraping  A Beautiful Planet
# {'domestic': 15650615, 'international': 10079505, 'worldwide': 25730120, 'budget': None, 'genres': ['155', 'theaters'], 'title': 'A Beautiful Planet'}
# scraping  I Was at Home, But...
# {'domestic': 14078, 'international': None, 'worldwide': 14078, 'budget': None, 'genres': ['4', 'theaters'], 'title': 'I Was at Home, But...'}
# scraping  Strike
# {'domestic': 15758, 'international': 8985, 'worldwide': 24743, 'budget': None, 'genres': ['2', 'theaters'], 'title': 'Strike'}
# scraping  The Cave
# {'domestic': 62625, 'international': 196296, 'worldwide': 258921, 'budget': None, 'genres': ['305', 'days/43', 'weeks'], 'title': 'The Cave'}
# scraping  The Kingmaker
# {'domestic': 122587, 'international': 26024, 'worldwide': 148611, 'budget': None, 'genres': ['284', 'days/40', 'weeks'], 'title': 'The Kingmaker'}
# scraping  Redoubt
# {'domestic': 33155, 'international': None, 'worldwide': 33155, 'budget': None, 'genres': ['3', 'theaters'], 'title': 'Redoubt'}
# scraping  Young Ahmed
# {'domestic': 21291, 'international': 52634, 'worldwide': 73925, 'budget': None, 'genres': ['4', 'theaters'], 'title': 'Young Ahmed'}
# scraping  Linda Ronstadt: The Sound of My Voice
# {'domestic': 4252657, 'international': None, 'worldwide': 4252657, 'budget': None, 'genres': ['347', 'days/49', 'weeks'], 'title': 'Linda Ronstadt: The Sound of My Voice'}
# scraping  Straight Up
# {'domestic': 16080, 'international': None, 'worldwide': 16080, 'budget': None, 'genres': ['5', 'theaters'], 'title': 'Straight Up'}
# scraping  Ballon
# {'domestic': 34222, 'international': 11765369, 'worldwide': 11799591, 'budget': None, 'genres': ['See', 'more', 'details', 'at', 'IMDbPro'], 'title': 'Ballon'}
# scraping  The Wild Goose Lake
# {'domestic': 12573, 'international': 31029840, 'worldwide': 31042413, 'budget': None, 'genres': ['5', 'theaters'], 'title': 'The Wild Goose Lake'}
# scraping  Sputnik
# {'domestic': 11024, 'international': None, 'worldwide': 11024, 'budget': None, 'genres': ['32', 'theaters'], 'title': 'Sputnik'}
# scraping  You Go to My Head
# {'domestic': 10682, 'international': None, 'worldwide': 10682, 'budget': None, 'genres': ['2', 'theaters'], 'title': 'You Go to My Head'}
# scraping  Playmobil: The Movie
# {'domestic': 1115008, 'international': 15234295, 'worldwide': 16349303, 'budget': None, 'genres': ['256', 'days/36', 'weeks'], 'title': 'Playmobil: The Movie'}
# scraping  Vitalina Varela
# {'domestic': 14941, 'international': 40921, 'worldwide': 55862, 'budget': None, 'genres': ['5', 'theaters'], 'title': 'Vitalina Varela'}
# scraping  The Grizzlies
# {'domestic': 10153, 'international': None, 'worldwide': 10153, 'budget': None, 'genres': ['18', 'days/2', 'weeks'], 'title': 'The Grizzlies'}
# scraping  The Last Tree
# {'domestic': 10128, 'international': 218548, 'worldwide': 228676, 'budget': None, 'genres': ['73', 'theaters'], 'title': 'The Last Tree'}
# scraping  Foosballers
# {'domestic': 9966, 'international': None, 'worldwide': 9966, 'budget': None, 'genres': ['See', 'more', 'details', 'at', 'IMDbPro'], 'title': 'Foosballers'}
# scraping  The Perfect Race
# {'domestic': 29644, 'international': None, 'worldwide': 29644, 'budget': None, 'genres': ['See', 'more', 'details', 'at', 'IMDbPro'], 'title': 'The Perfect Race'}
# scraping  The Truth
# {'domestic': 9619, 'international': 5233647, 'worldwide': 5243266, 'budget': None, 'genres': ['46', 'days/6', 'weeks'], 'title': 'The Truth'}
# scraping  Under the Sea 3D
# {'domestic': 36262926, 'international': 19639698, 'worldwide': 55902624, 'budget': None, 'genres': ['108', 'theaters'], 'title': 'Under the Sea 3D'}
# scraping  Kind Hearts and Coronets
# {'domestic': 35948, 'international': 44847, 'worldwide': 80795, 'budget': None, 'genres': ['3', 'theaters'], 'title': 'Kind Hearts and Coronets'}
# scraping  The Trip to Greece
# {'domestic': 8340, 'international': 224674, 'worldwide': 233014, 'budget': None, 'genres': ['11', 'theaters'], 'title': 'The Trip to Greece'}
# scraping  Inside the Rain
# {'domestic': 8140, 'international': None, 'worldwide': 8140, 'budget': None, 'genres': ['1', 'theater'], 'title': 'Inside the Rain'}
# scraping  The Wave
# {'domestic': 8101, 'international': None, 'worldwide': 8101, 'budget': None, 'genres': ['13', 'theaters'], 'title': 'The Wave'}
# scraping  Black and Blue
# {'domestic': 22055313, 'international': 685748, 'worldwide': 22741061, 'budget': 12000000, 'genres': ['Action', 'Crime', 'Drama', 'Thriller'], 'title': 'Black and Blue'}
# scraping  American Dharma
# {'domestic': 51891, 'international': None, 'worldwide': 51891, 'budget': None, 'genres': ['291', 'days/41', 'weeks'], 'title': 'American Dharma'}
# scraping  Resistance
# {'domestic': 7464, 'international': 271114, 'worldwide': 278578, 'budget': None, 'genres': ['1', 'theater'], 'title': 'Resistance'}
# scraping  Circles
# {'domestic': 10260, 'international': None, 'worldwide': 10260, 'budget': None, 'genres': [], 'title': 'Circles'}
# scraping  What We Found
# {'domestic': 6761, 'international': None, 'worldwide': 6761, 'budget': None, 'genres': ['8', 'theaters'], 'title': 'What We Found'}
# scraping  Human Capital
# {'domestic': 6596, 'international': None, 'worldwide': 6596, 'budget': None, 'genres': ['12', 'theaters'], 'title': 'Human Capital'}
# scraping  Afterward
# {'domestic': 6477, 'international': None, 'worldwide': 6477, 'budget': None, 'genres': ['1', 'theater'], 'title': 'Afterward'}
# scraping  By the Grace of God
# {'domestic': 67059, 'international': 7688593, 'worldwide': 7755652, 'budget': None, 'genres': ['11', 'theaters'], 'title': 'By the Grace of God'}
# scraping  Hubble 3D
# {'domestic': 52522904, 'international': 21726825, 'worldwide': 74249729, 'budget': None, 'genres': ['151', 'theaters'], 'title': 'Hubble 3D'}
# scraping  The Other Lamb
# {'domestic': 6024, 'international': 736, 'worldwide': 6760, 'budget': None, 'genres': ['1', 'theater'], 'title': 'The Other Lamb'}
# scraping  Human Nature
# {'domestic': 5487, 'international': 347, 'worldwide': 5834, 'budget': None, 'genres': ['2', 'theaters'], 'title': 'Human Nature'}
# scraping  Matthias & Maxime
# {'domestic': 374739, 'international': 1466139, 'worldwide': 1840878, 'budget': None, 'genres': ['53', 'theaters'], 'title': 'Matthias & Maxime'}
# scraping  Que Leones
# {'domestic': 822828, 'international': None, 'worldwide': 822828, 'budget': None, 'genres': ['See', 'more', 'details', 'at', 'IMDbPro'], 'title': 'Que Leones'}
# scraping  The Disappearance of My Mother
# {'domestic': 24951, 'international': 58979, 'worldwide': 83930, 'budget': None, 'genres': ['See', 'more', 'details', 'at', 'IMDbPro'], 'title': 'The Disappearance of My Mother'}
# scraping  Sympathy for the Devil
# {'domestic': 51150, 'international': 63151, 'worldwide': 114301, 'budget': None, 'genres': ['8', 'theaters'], 'title': 'Sympathy for the Devil'}
# scraping  Tremors
# {'domestic': 23911, 'international': 97902, 'worldwide': 121813, 'budget': None, 'genres': ['6', 'theaters'], 'title': 'Tremors'}
# scraping  Blood Widow
# {'domestic': 6047, 'international': None, 'worldwide': 6047, 'budget': None, 'genres': ['See', 'more', 'details', 'at', 'IMDbPro'], 'title': 'Blood Widow'}
# scraping  Just One More Kiss
# {'domestic': 9130, 'international': None, 'worldwide': 9130, 'budget': None, 'genres': ['2', 'theaters'], 'title': 'Just One More Kiss'}
# scraping  Give Me Liberty
# {'domestic': 242734, 'international': 382084, 'worldwide': 624818, 'budget': None, 'genres': ['18', 'theaters'], 'title': 'Give Me Liberty'}
# scraping  Babyteeth
# {'domestic': 4507, 'international': 193739, 'worldwide': 198246, 'budget': None, 'genres': ['12', 'theaters'], 'title': 'Babyteeth'}
# scraping  Deep Sea
# {'domestic': 46412757, 'international': 51818148, 'worldwide': 98230905, 'budget': None, 'genres': ['5,282', 'days/754', 'weeks'], 'title': 'Deep Sea'}
# scraping  Lost in America
# {'domestic': 11301, 'international': None, 'worldwide': 11301, 'budget': None, 'genres': ['2', 'theaters'], 'title': 'Lost in America'}
# scraping  Stuffed
# {'domestic': 15532, 'international': None, 'worldwide': 15532, 'budget': None, 'genres': ['3', 'theaters'], 'title': 'Stuffed'}
# scraping  Maiden
# {'domestic': 3168978, 'international': 326263, 'worldwide': 3495241, 'budget': None, 'genres': ['417', 'days/59', 'weeks'], 'title': 'Maiden'}
# scraping  Aquarela
# {'domestic': 307346, 'international': 331561, 'worldwide': 638907, 'budget': None, 'genres': ['368', 'days/52', 'weeks'], 'title': 'Aquarela'}
# scraping  A Bigger Splash
# {'domestic': 95826, 'international': None, 'worldwide': 95826, 'budget': None, 'genres': ['11', 'theaters'], 'title': 'A Bigger Splash'}
# scraping  The Roads Not Taken
# {'domestic': 3518, 'international': None, 'worldwide': 3518, 'budget': None, 'genres': ['158', 'days/22', 'weeks'], 'title': 'The Roads Not Taken'}
# scraping  Guest Artist
# {'domestic': 6555, 'international': None, 'worldwide': 6555, 'budget': None, 'genres': ['2', 'theaters'], 'title': 'Guest Artist'}
# scraping  Mr. Klein
# {'domestic': 193028, 'international': None, 'worldwide': 193028, 'budget': None, 'genres': ['6', 'theaters'], 'title': 'Mr. Klein'}
# scraping  Ága
# {'domestic': 35178, 'international': None, 'worldwide': 35178, 'budget': None, 'genres': ['3', 'theaters'], 'title': 'Ága'}
# scraping  The Hottest August
# {'domestic': 9163, 'international': None, 'worldwide': 9163, 'budget': None, 'genres': ['2', 'theaters'], 'title': 'The Hottest August'}
# scraping  Killing Sarai
# {'domestic': 425332, 'international': None, 'worldwide': 425332, 'budget': None, 'genres': ['256', 'days/36', 'weeks'], 'title': 'Killing Sarai'}
# scraping  Chinese Portrait
# {'domestic': 4140, 'international': None, 'worldwide': 4140, 'budget': None, 'genres': ['2', 'theaters'], 'title': 'Chinese Portrait'}
# scraping  Hustlers
# {'domestic': 104963598, 'international': 52600000, 'worldwide': 157563598, 'budget': 20000000, 'genres': ['Comedy', 'Crime', 'Drama', 'Thriller'], 'title': 'Hustlers'}
# scraping  Sex and the Future
# {'domestic': 3101, 'international': None, 'worldwide': 3101, 'budget': None, 'genres': ['2', 'theaters'], 'title': 'Sex and the Future'}
# scraping  Killer Raccoons 2: Dark Christmas in the Dark
# {'domestic': 6780, 'international': None, 'worldwide': 6780, 'budget': None, 'genres': ['4', 'theaters'], 'title': 'Killer Raccoons 2: Dark Christmas in the Dark'}
# scraping  Powerbomb
# {'domestic': 11319, 'international': None, 'worldwide': 11319, 'budget': None, 'genres': ['3', 'theaters'], 'title': 'Powerbomb'}
# scraping  Light from Light
# {'domestic': 24808, 'international': None, 'worldwide': 24808, 'budget': None, 'genres': ['5', 'theaters'], 'title': 'Light from Light'}
# scraping  Moondance
# {'domestic': 2371, 'international': None, 'worldwide': 2371, 'budget': None, 'genres': ['9', 'theaters'], 'title': 'Moondance'}
# scraping  Goldie
# {'domestic': 2302, 'international': None, 'worldwide': 2302, 'budget': None, 'genres': ['10', 'theaters'], 'title': 'Goldie'}
# scraping  Duet for Cannibals
# {'domestic': 12962, 'international': None, 'worldwide': 12962, 'budget': None, 'genres': ['See', 'more', 'details', 'at', 'IMDbPro'], 'title': 'Duet for Cannibals'}
# scraping  Little Joe
# {'domestic': 23862, 'international': 174812, 'worldwide': 198674, 'budget': None, 'genres': ['12', 'theaters'], 'title': 'Little Joe'}
# scraping  Frankie
# {'domestic': 171781, 'international': 523899, 'worldwide': 695680, 'budget': None, 'genres': ['298', 'days/42', 'weeks'], 'title': 'Frankie'}
# scraping  Bump Kowalski and the Ten Commandments
# {'domestic': 1899, 'international': None, 'worldwide': 1899, 'budget': None, 'genres': [], 'title': 'Bump Kowalski and the Ten Commandments'}
# scraping  Christ Stopped at Eboli
# {'domestic': 78736, 'international': None, 'worldwide': 78736, 'budget': None, 'genres': ['3', 'theaters'], 'title': 'Christ Stopped at Eboli'}
# scraping  To the Arctic 3D
# {'domestic': 14560838, 'international': 9134550, 'worldwide': 23695388, 'budget': None, 'genres': ['3,042', 'days/434', 'weeks'], 'title': 'To the Arctic 3D'}
# scraping  Be Natural: The Untold Story of Alice Guy-Blaché
# {'domestic': 115685, 'international': 49934, 'worldwide': 165619, 'budget': None, 'genres': ['14', 'theaters'], 'title': 'Be Natural: The Untold Story of Alice Guy-Blaché'}
# scraping  Edie
# {'domestic': 71790, 'international': 2659380, 'worldwide': 2731170, 'budget': None, 'genres': ['11', 'theaters'], 'title': 'Edie'}
# scraping  The Painted Bird
# {'domestic': 1460, 'international': 577566, 'worldwide': 579026, 'budget': None, 'genres': ['8', 'theaters'], 'title': 'The Painted Bird'}
# scraping  End of the Century
# {'domestic': 66309, 'international': 13298, 'worldwide': 79607, 'budget': None, 'genres': ['6', 'theaters'], 'title': 'End of the Century'}
# scraping  Space Station 3D
# {'domestic': 93383953, 'international': 34979928, 'worldwide': 128363881, 'budget': None, 'genres': ['64', 'theaters'], 'title': 'Space Station 3D'}
# scraping  I'll Take Your Dead
# {'domestic': 8994, 'international': None, 'worldwide': 8994, 'budget': None, 'genres': ['5', 'theaters'], 'title': "I'll Take Your Dead"}
# scraping  Hai Tang Hong
# {'domestic': 1107, 'international': None, 'worldwide': 1107, 'budget': None, 'genres': ['See', 'more', 'details', 'at', 'IMDbPro'], 'title': 'Hai Tang Hong'}
# scraping  The Gliksmans
# {'domestic': 5166, 'international': None, 'worldwide': 5166, 'budget': None, 'genres': ['3', 'theaters'], 'title': 'The Gliksmans'}
# scraping  The Fox Hunter
# {'domestic': 1577, 'international': None, 'worldwide': 1577, 'budget': None, 'genres': ['See', 'more', 'details', 'at', 'IMDbPro'], 'title': 'The Fox Hunter'}
# scraping  In the Life of Music
# {'domestic': 897, 'international': None, 'worldwide': 897, 'budget': None, 'genres': ['1', 'theater'], 'title': 'In the Life of Music'}
# scraping  King's Gambit
# {'domestic': 3816, 'international': None, 'worldwide': 3816, 'budget': None, 'genres': ['2', 'theaters'], 'title': "King's Gambit"}
# scraping  The Transcendents
# {'domestic': 1090, 'international': None, 'worldwide': 1090, 'budget': None, 'genres': ['1', 'theater'], 'title': 'The Transcendents'}
# scraping  Millennium Actress
# {'domestic': 225250, 'international': None, 'worldwide': 225250, 'budget': None, 'genres': ['512', 'theaters'], 'title': 'Millennium Actress'}
# scraping  Spiral Farm
# {'domestic': 6517, 'international': None, 'worldwide': 6517, 'budget': None, 'genres': ['3', 'theaters'], 'title': 'Spiral Farm'}
# scraping  A German Youth
# {'domestic': 2343, 'international': None, 'worldwide': 2343, 'budget': None, 'genres': ['1', 'theater'], 'title': 'A German Youth'}
# scraping  Hyenas
# {'domestic': 24672, 'international': None, 'worldwide': 24672, 'budget': None, 'genres': ['See', 'more', 'details', 'at', 'IMDbPro'], 'title': 'Hyenas'}
# scraping  Island of Lemurs: Madagascar
# {'domestic': 11272213, 'international': 2794321, 'worldwide': 14066534, 'budget': None, 'genres': ['302', 'theaters'], 'title': 'Island of Lemurs: Madagascar'}
# scraping  I Do Not Care If We Go Down in History as Barbarians
# {'domestic': 11307, 'international': 27864, 'worldwide': 39171, 'budget': None, 'genres': ['2', 'theaters'], 'title': 'I Do Not Care If We Go Down in History as Barbarians'}
# scraping  The Load
# {'domestic': 28410, 'international': None, 'worldwide': 28410, 'budget': None, 'genres': ['2', 'theaters'], 'title': 'The Load'}
# scraping  Asako I & II
# {'domestic': 25559, 'international': 601543, 'worldwide': 627102, 'budget': None, 'genres': ['3', 'theaters'], 'title': 'Asako I & II'}
# scraping  Chained for Life
# {'domestic': 17431, 'international': None, 'worldwide': 17431, 'budget': None, 'genres': ['3', 'theaters'], 'title': 'Chained for Life'}
# scraping  Shooting the Mafia
# {'domestic': 10881, 'international': 21161, 'worldwide': 32042, 'budget': None, 'genres': ['3', 'theaters'], 'title': 'Shooting the Mafia'}

# %%
bom_df_2020 = pd.DataFrame.from_dict(movie_dict_2020,orient="index")
bom_df_2020.head()
# Out:
#                                              domestic  international  \
# /release/rl1182631425/?ref_=bo_yld_table_1  204417855    220200000.0
# /release/rl2969994753/?ref_=bo_yld_table_2  159227644    221775855.0
# /release/rl4244997633/?ref_=bo_yld_table_3  146066470    160700000.0
# /release/rl755467777/?ref_=bo_yld_table_4   316831246    479744747.0
# /release/rl3305145857/?ref_=bo_yld_table_5  515202542    558941706.0
#
#                                              worldwide       budget  \
# /release/rl1182631425/?ref_=bo_yld_table_1   424617855   90000000.0
# /release/rl2969994753/?ref_=bo_yld_table_2   381003499   95000000.0
# /release/rl4244997633/?ref_=bo_yld_table_3   306766470   85000000.0
# /release/rl755467777/?ref_=bo_yld_table_4    796575993  125000000.0
# /release/rl3305145857/?ref_=bo_yld_table_5  1074144248  275000000.0
#
#                                                                                  genres  \
# /release/rl1182631425/?ref_=bo_yld_table_1            [Action, Comedy, Crime, Thriller]
# /release/rl2969994753/?ref_=bo_yld_table_2                                 [Drama, War]
# /release/rl4244997633/?ref_=bo_yld_table_3  [Action, Adventure, Comedy, Family, Sci-Fi]
# /release/rl755467777/?ref_=bo_yld_table_4          [Action, Adventure, Comedy, Fantasy]
# /release/rl3305145857/?ref_=bo_yld_table_5         [Action, Adventure, Fantasy, Sci-Fi]
#
#                                                                        title
# /release/rl1182631425/?ref_=bo_yld_table_1                 Bad Boys for Life
# /release/rl2969994753/?ref_=bo_yld_table_2                              1917
# /release/rl4244997633/?ref_=bo_yld_table_3                Sonic the Hedgehog
# /release/rl755467777/?ref_=bo_yld_table_4            Jumanji: The Next Level
# /release/rl3305145857/?ref_=bo_yld_table_5  Star Wars: The Rise of Skywalker

# %%
bom_df_2020.to_csv("zippedData/bom-budget-and-genres-2020.csv")
