# %%
import requests
import sys
import numpy as np
import time
import pandas as pd
from bs4 import BeautifulSoup
#time.sleep(1)

# %%
def get_links(year):
    """returns a list of link suffixes that connect to every movie in the
    boxofficemojo page for the given year"""
    page = requests.get("https://www.boxofficemojo.com/year/{}/".format(year))
    soup = BeautifulSoup(page.content, 'html.parser')
    if page.status_code >=400:
        return [page.status_code,"https://www.boxofficemojo.com/year/{}/".format(year)]
    links = soup.select(".a-text-left.mojo-field-type-release.mojo-cell-wide a")
    return links

# %%
def cash_str_to_int(string):
    #takes string containing a number with a symbol at the front and returns the int
    return int(string[1:].replace(",",""))

# %%
def make_movie_dict(links):
    """accepts a list of link suffixes and returns a dictionary that
    has a key for each link. The value of each item is also a dictionary
    containing keys
                    domestic, international, worldwide, budget, genres, and title,
    with types      float     float          float      float   list[strs]   str
    
    if an int is missing its replaced with none and if genres is missing it is
    replaced with an empty list
    """
    movie_dict = {}
    for link in links:
        time.sleep(np.random.random())
        current = requests.get("https://www.boxofficemojo.com" + link["href"])
        currysoup = BeautifulSoup(current.content, "html.parser")
        try:
            title = currysoup.find("h1").text
        except AttributeError:
            title = None
        ##print("scraping ", title)
        try:
            budget = cash_str_to_int(currysoup.find(text="Budget").next_element.text)
        except AttributeError:
            budget = None
        grossli = currysoup.select(".a-section.a-spacing-none.mojo-performance-summary-table .a-section.a-spacing-none")
        grosses = []
        for i in grossli:
            try:
                grosses.append(cash_str_to_int(i.select(".money")[0].text))
            except IndexError:
                grosses.append(None)
        try:
            genres = currysoup.find(text = "Genres").next_element.text.split()##[1].text.split()
            ##print(genres)
        except AttributeError:
            genres = []
        movie_dict[link["href"]] = {"domestic":grosses[0],
                                    "international":grosses[1],
                                    "worldwide":grosses[2],
                                    "budget":budget,
                                    "genres":genres,
                                    "title":title
                                   }
        ##print(movie_dict[link["href"]])
        #uncomment the below to see only one pull
        #return(movie_dict)
    return movie_dict

# %%
##Creating a dictionary with keys that are year integers 
##and values that are dictionaries from the make_movie_dict function
##Running a for loop to scrape all years

for year in range(2005,2021):
    current_links = get_links(year)
    movie_dict[year] = make_movie_dict(current_links)
    print(year)
# Out:
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
# 2020

# %%
movie_dict[2018]
# Out:
# {'/release/rl2992866817/?ref_=bo_yld_table_1': {'domestic': 700059566,
#   'international': 646853595,
#   'worldwide': 1346913161,
#   'budget': None,
#   'genres': ['Action', 'Adventure', 'Sci-Fi'],
#   'title': 'Black Panther'},
#  '/release/rl3043198465/?ref_=bo_yld_table_2': {'domestic': 678815482,
#   'international': 1369544272,
#   'worldwide': 2048359754,
#   'budget': None,
#   'genres': ['Action', 'Adventure', 'Sci-Fi'],
#   'title': 'Avengers: Infinity War'},
#  '/release/rl2071758337/?ref_=bo_yld_table_3': {'domestic': 608581744,
#   'international': 634223615,
#   'worldwide': 1242805359,
#   'budget': None,
#   'genres': ['Action', 'Adventure', 'Animation', 'Comedy', 'Family', 'Sci-Fi'],
#   'title': 'The Incredibles 2'},
#  '/release/rl1602061825/?ref_=bo_yld_table_4': {'domestic': 417719760,
#   'international': 890748184,
#   'worldwide': 1308467944,
#   'budget': 170000000,
#   'genres': ['Action', 'Adventure', 'Sci-Fi'],
#   'title': 'Jurassic World: Fallen Kingdom'},
#  '/release/rl2488436225/?ref_=bo_yld_table_5': {'domestic': 318491426,
#   'international': 416055185,
#   'worldwide': 734546611,
#   'budget': 110000000,
#   'genres': ['Action', 'Adventure', 'Comedy', 'Sci-Fi'],
#   'title': 'Deadpool 2'},
#  '/release/rl3075966465/?ref_=bo_yld_table_6': {'domestic': 270620950,
#   'international': 240975007,
#   'worldwide': 511595957,
#   'budget': 75000000,
#   'genres': ['Animation', 'Comedy', 'Family', 'Fantasy'],
#   'title': "Dr. Seuss' the Grinch"},
#  '/release/rl3095234049/?ref_=bo_yld_table_7': {'domestic': 404515480,
#   'international': 557562066,
#   'worldwide': 962077546,
#   'budget': 90000000,
#   'genres': ['Action', 'Adventure', 'Comedy', 'Fantasy'],
#   'title': 'Jumanji: Welcome to the Jungle'},
#  '/release/rl2449573377/?ref_=bo_yld_table_8': {'domestic': 220159104,
#   'international': 570956000,
#   'worldwide': 791115104,
#   'budget': 178000000,
#   'genres': ['Action', 'Adventure', 'Thriller'],
#   'title': 'Mission: Impossible - Fallout'},
#  '/release/rl2088535553/?ref_=bo_yld_table_9': {'domestic': 216648740,
#   'international': 406025399,
#   'worldwide': 622674139,
#   'budget': None,
#   'genres': ['Action', 'Adventure', 'Comedy', 'Sci-Fi'],
#   'title': 'Ant-Man and the Wasp'},
#  '/release/rl1954383361/?ref_=bo_yld_table_10': {'domestic': 213767512,
#   'international': 179157295,
#   'worldwide': 392924807,
#   'budget': 275000000,
#   'genres': ['Action', 'Adventure', 'Sci-Fi'],
#   'title': 'Solo: A Star Wars Story'},
#  '/release/rl2734720513/?ref_=bo_yld_table_11': {'domestic': 213515506,
#   'international': 642569645,
#   'worldwide': 856085151,
#   'budget': 100000000,
#   'genres': ['Action', 'Adventure', 'Sci-Fi', 'Thriller'],
#   'title': 'Venom'},
#  '/release/rl2164360705/?ref_=bo_yld_table_12': {'domestic': 215288866,
#   'international': 220900000,
#   'worldwide': 436188866,
#   'budget': 36000000,
#   'genres': ['Drama', 'Music', 'Romance'],
#   'title': 'A Star Is Born'},
#  '/release/rl3108800001/?ref_=bo_yld_table_13': {'domestic': 335061807,
#   'international': 813400000,
#   'worldwide': 1148461807,
#   'budget': None,
#   'genres': ['Action', 'Adventure', 'Fantasy', 'Sci-Fi'],
#   'title': 'Aquaman'},
#  '/release/rl3439363585/?ref_=bo_yld_table_14': {'domestic': 216428042,
#   'international': 687227217,
#   'worldwide': 903655259,
#   'budget': 52000000,
#   'genres': ['Biography', 'Drama', 'Music'],
#   'title': 'Bohemian Rhapsody'},
#  '/release/rl2399176193/?ref_=bo_yld_table_15': {'domestic': 188024361,
#   'international': 152915000,
#   'worldwide': 340939361,
#   'budget': 17000000,
#   'genres': ['Drama', 'Horror', 'Sci-Fi'],
#   'title': 'A Quiet Place'},
#  '/release/rl2742978049/?ref_=bo_yld_table_16': {'domestic': 201091711,
#   'international': 328232251,
#   'worldwide': 529323962,
#   'budget': 175000000,
#   'genres': ['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy'],
#   'title': 'Ralph Breaks the Internet'},
#  '/release/rl1157858817/?ref_=bo_yld_table_17': {'domestic': 174532921,
#   'international': 64000000,
#   'worldwide': 238532921,
#   'budget': 30000000,
#   'genres': ['Comedy', 'Drama', 'Romance'],
#   'title': 'Crazy Rich Asians'},
#  '/release/rl3111945729/?ref_=bo_yld_table_18': {'domestic': 167510016,
#   'international': 361073758,
#   'worldwide': 528583774,
#   'budget': 80000000,
#   'genres': ['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy'],
#   'title': 'Hotel Transylvania 3: Summer Vacation'},
#  '/release/rl1342342657/?ref_=bo_yld_table_19': {'domestic': 159342015,
#   'international': 96143163,
#   'worldwide': 255485178,
#   'budget': 10000000,
#   'genres': ['Crime', 'Horror', 'Thriller'],
#   'title': 'Halloween'},
#  '/release/rl1534625281/?ref_=bo_yld_table_20': {'domestic': 159555901,
#   'international': 495300000,
#   'worldwide': 654855901,
#   'budget': 200000000,
#   'genres': ['Adventure', 'Family', 'Fantasy'],
#   'title': 'Fantastic Beasts: The Crimes of Grindelwald'},
#  '/release/rl2105509377/?ref_=bo_yld_table_21': {'domestic': 145443742,
#   'international': 384800000,
#   'worldwide': 530243742,
#   'budget': 130000000,
#   'genres': ['Action', 'Horror', 'Sci-Fi', 'Thriller'],
#   'title': 'The Meg'},
#  '/release/rl2206107137/?ref_=bo_yld_table_22': {'domestic': 140218711,
#   'international': 157500000,
#   'worldwide': 297718711,
#   'budget': 70000000,
#   'genres': ['Action', 'Comedy', 'Crime', 'Thriller'],
#   'title': "Ocean's 8"},
#  '/release/rl2977793537/?ref_=bo_yld_table_23': {'domestic': 137690172,
#   'international': 445200000,
#   'worldwide': 582890172,
#   'budget': 175000000,
#   'genres': ['Action', 'Adventure', 'Sci-Fi'],
#   'title': 'Ready Player One'},
#  '/release/rl1700234753/?ref_=bo_yld_table_24': {'domestic': 174340174,
#   'international': 260653009,
#   'worldwide': 434993183,
#   'budget': 84000000,
#   'genres': ['Biography', 'Drama', 'Musical'],
#   'title': 'The Greatest Showman'},
#  '/release/rl1828947457/?ref_=bo_yld_table_25': {'domestic': 120634935,
#   'international': 274409771,
#   'worldwide': 395044706,
#   'budget': 75000000,
#   'genres': ['Comedy', 'Musical', 'Romance'],
#   'title': 'Mamma Mia! Here We Go Again'},
#  '/release/rl1493206529/?ref_=bo_yld_table_26': {'domestic': 117450119,
#   'international': 248100000,
#   'worldwide': 365550119,
#   'budget': 22000000,
#   'genres': ['Horror', 'Mystery', 'Thriller'],
#   'title': 'The Nun'},
#  '/release/rl3380381185/?ref_=bo_yld_table_27': {'domestic': 115253424,
#   'international': 236013009,
#   'worldwide': 351266433,
#   'budget': 50000000,
#   'genres': ['Adventure', 'Comedy', 'Family', 'Fantasy'],
#   'title': 'Peter Rabbit'},
#  '/release/rl1594197505/?ref_=bo_yld_table_28': {'domestic': 115715889,
#   'international': 98500000,
#   'worldwide': 214215889,
#   'budget': 50000000,
#   'genres': ['Drama', 'Sport'],
#   'title': 'Creed II'},
#  '/release/rl879986177/?ref_=bo_yld_table_29': {'domestic': 190241310,
#   'international': 185299521,
#   'worldwide': 375540831,
#   'budget': None,
#   'genres': ['Action', 'Adventure', 'Animation', 'Family', 'Sci-Fi'],
#   'title': 'Spider-Man: Into the Spider-Verse'},
#  '/release/rl3263137281/?ref_=bo_yld_table_30': {'domestic': 171958438,
#   'international': 177579056,
#   'worldwide': 349537494,
#   'budget': 130000000,
#   'genres': ['Comedy', 'Family', 'Fantasy', 'Musical'],
#   'title': 'Mary Poppins Returns'},
#  '/release/rl2708702721/?ref_=bo_yld_table_31': {'domestic': 620181382,
#   'international': 712358507,
#   'worldwide': 1332539889,
#   'budget': 317000000,
#   'genres': ['Action', 'Adventure', 'Fantasy', 'Sci-Fi'],
#   'title': 'Star Wars: Episode VIII - The Last Jedi'},
#  '/release/rl494765569/?ref_=bo_yld_table_32': {'domestic': 102084362,
#   'international': 88315795,
#   'worldwide': 190400157,
#   'budget': 62000000,
#   'genres': ['Action', 'Crime', 'Thriller'],
#   'title': 'The Equalizer 2'},
#  '/release/rl2122286593/?ref_=bo_yld_table_33': {'domestic': 101028233,
#   'international': 327000000,
#   'worldwide': 428028233,
#   'budget': 120000000,
#   'genres': ['Action', 'Adventure', 'Sci-Fi'],
#   'title': 'Rampage'},
#  '/release/rl3229582849/?ref_=bo_yld_table_34': {'domestic': 100478608,
#   'international': 32197256,
#   'worldwide': 132675864,
#   'budget': None,
#   'genres': ['Adventure', 'Family', 'Fantasy', 'Sci-Fi'],
#   'title': 'A Wrinkle in Time'},
#  '/release/rl4014048769/?ref_=bo_yld_table_35': {'domestic': 100407760,
#   'international': 271577258,
#   'worldwide': 371985018,
#   'budget': 55000000,
#   'genres': ['Drama', 'Romance', 'Thriller'],
#   'title': 'Fifty Shades Freed'},
#  '/release/rl2105312769/?ref_=bo_yld_table_36': {'domestic': 99215042,
#   'international': 98529335,
#   'worldwide': 197744377,
#   'budget': 75000000,
#   'genres': ['Comedy', 'Drama', 'Family', 'Fantasy'],
#   'title': 'Christopher Robin'},
#  '/release/rl537036289/?ref_=bo_yld_table_37': {'domestic': 83482352,
#   'international': 2604529,
#   'worldwide': 86086881,
#   'budget': 7000000,
#   'genres': ['Biography', 'Drama', 'Family', 'Music'],
#   'title': 'I Can Only Imagine'},
#  '/release/rl419661313/?ref_=bo_yld_table_38': {'domestic': 83240103,
#   'international': 130800000,
#   'worldwide': 214040103,
#   'budget': None,
#   'genres': ['Adventure',
#    'Animation',
#    'Comedy',
#    'Family',
#    'Fantasy',
#    'Musical'],
#   'title': 'Smallfoot'},
#  '/release/rl3590358529/?ref_=bo_yld_table_39': {'domestic': 81903458,
#   'international': 97865999,
#   'worldwide': 179769457,
#   'budget': 50000000,
#   'genres': ['Drama', 'Thriller'],
#   'title': 'The Post'},
#  '/release/rl3909125633/?ref_=bo_yld_table_40': {'domestic': 77339130,
#   'international': 25766748,
#   'worldwide': 103105878,
#   'budget': 29000000,
#   'genres': ['Comedy'],
#   'title': 'Night School'},
#  '/release/rl2139063809/?ref_=bo_yld_table_41': {'domestic': 127195589,
#   'international': 340794056,
#   'worldwide': 467989645,
#   'budget': 135000000,
#   'genres': ['Action', 'Adventure', 'Sci-Fi'],
#   'title': 'Bumblebee'},
#  '/release/rl1526760961/?ref_=bo_yld_table_42': {'domestic': 69488745,
#   'international': 67567517,
#   'worldwide': 137056262,
#   'budget': 13000000,
#   'genres': ['Action', 'Horror', 'Sci-Fi', 'Thriller'],
#   'title': 'The First Purge'},
#  '/release/rl1744864769/?ref_=bo_yld_table_43': {'domestic': 69179066,
#   'international': 48500000,
#   'worldwide': 117679066,
#   'budget': 37000000,
#   'genres': ['Action', 'Comedy', 'Crime', 'Mystery', 'Thriller'],
#   'title': 'Game Night'},
#  '/release/rl3053815297/?ref_=bo_yld_table_44': {'domestic': 68566296,
#   'international': 35871892,
#   'worldwide': 104438188,
#   'budget': None,
#   'genres': ['Comedy', 'Drama', 'Romance'],
#   'title': 'Book Club'},
#  '/release/rl1157793281/?ref_=bo_yld_table_45': {'domestic': 68549695,
#   'international': 62907452,
#   'worldwide': 131457147,
#   'budget': 42000000,
#   'genres': ['Comedy', 'Family', 'Fantasy', 'Sci-Fi'],
#   'title': 'The House with a Clock in Its Walls'},
#  '/release/rl2936047105/?ref_=bo_yld_table_46': {'domestic': 68420120,
#   'international': 236448841,
#   'worldwide': 304868961,
#   'budget': 125000000,
#   'genres': ['Action', 'Adventure', 'Thriller'],
#   'title': 'Skyscraper'},
#  '/release/rl394167809/?ref_=bo_yld_table_47': {'domestic': 67745330,
#   'international': 100140258,
#   'worldwide': 167885588,
#   'budget': 10000000,
#   'genres': ['Horror', 'Mystery', 'Thriller'],
#   'title': 'Insidious: The Last Key'},
#  '/release/rl235243009/?ref_=bo_yld_table_48': {'domestic': 67363237,
#   'international': 53192964,
#   'worldwide': 120556201,
#   'budget': 48000000,
#   'genres': ['Comedy', 'Drama'],
#   'title': 'Instant Family'},
#  '/release/rl4077356545/?ref_=bo_yld_table_49': {'domestic': 103804407,
#   'international': 71000000,
#   'worldwide': 174804407,
#   'budget': 50000000,
#   'genres': ['Crime', 'Drama', 'Thriller'],
#   'title': 'The Mule'},
#  '/release/rl1048479233/?ref_=bo_yld_table_50': {'domestic': 60311495,
#   'international': 33705799,
#   'worldwide': 94017294,
#   'budget': 21000000,
#   'genres': ['Comedy'],
#   'title': 'Blockers'},
#  '/release/rl1382647297/?ref_=bo_yld_table_51': {'domestic': 59874525,
#   'international': 231055623,
#   'worldwide': 290930148,
#   'budget': 150000000,
#   'genres': ['Action', 'Adventure', 'Sci-Fi'],
#   'title': 'Pacific Rim: Uprising'},
#  '/release/rl1179420161/?ref_=bo_yld_table_52': {'domestic': 58250803,
#   'international': 216400000,
#   'worldwide': 274650803,
#   'budget': 94000000,
#   'genres': ['Action', 'Adventure', 'Fantasy', 'Thriller'],
#   'title': 'Tomb Raider'},
#  '/release/rl3663955457/?ref_=bo_yld_table_53': {'domestic': 58032443,
#   'international': 230142892,
#   'worldwide': 288175335,
#   'budget': 62000000,
#   'genres': ['Action', 'Adventure', 'Sci-Fi', 'Thriller'],
#   'title': 'Maze Runner: The Death Cure'},
#  '/release/rl654542337/?ref_=bo_yld_table_54': {'domestic': 54730625,
#   'international': 23400000,
#   'worldwide': 78130625,
#   'budget': 28000000,
#   'genres': ['Action', 'Comedy'],
#   'title': 'Tag'},
#  '/release/rl3657664001/?ref_=bo_yld_table_55': {'domestic': 54858851,
#   'international': 119102218,
#   'worldwide': 173961069,
#   'budget': 120000000,
#   'genres': ['Adventure', 'Family', 'Fantasy'],
#   'title': 'The Nutcracker and the Four Realms'},
#  '/release/rl4261774849/?ref_=bo_yld_table_56': {'domestic': 53548586,
#   'international': 44096031,
#   'worldwide': 97644617,
#   'budget': 20000000,
#   'genres': ['Comedy', 'Crime', 'Drama', 'Mystery', 'Thriller'],
#   'title': 'A Simple Favor'},
#  '/release/rl2256438785/?ref_=bo_yld_table_57': {'domestic': 53059911,
#   'international': 12800000,
#   'worldwide': 65859911,
#   'budget': None,
#   'genres': ['Comedy'],
#   'title': 'Life of the Party'},
#  '/release/rl1082099201/?ref_=bo_yld_table_58': {'domestic': 51024708,
#   'international': 109517426,
#   'worldwide': 160542134,
#   'budget': 88000000,
#   'genres': ['Action', 'Adventure', 'Sci-Fi', 'Thriller'],
#   'title': 'The Predator'},
#  '/release/rl3707995649/?ref_=bo_yld_table_59': {'domestic': 50316123,
#   'international': 40928790,
#   'worldwide': 91244913,
#   'budget': 12000000,
#   'genres': ['Comedy', 'Romance'],
#   'title': 'Overboard'},
#  '/release/rl771917313/?ref_=bo_yld_table_60': {'domestic': 50072235,
#   'international': 25765508,
#   'worldwide': 75837743,
#   'budget': 35000000,
#   'genres': ['Action', 'Adventure', 'Crime', 'Drama', 'Mystery', 'Thriller'],
#   'title': 'Sicario: Day of the Soldado'},
#  '/release/rl3959653889/?ref_=bo_yld_table_61': {'domestic': 48795601,
#   'international': 45743825,
#   'worldwide': 94539426,
#   'budget': 32000000,
#   'genres': ['Comedy', 'Romance'],
#   'title': 'I Feel Pretty'},
#  '/release/rl1862567425/?ref_=bo_yld_table_62': {'domestic': 49275340,
#   'international': 44125483,
#   'worldwide': 93400823,
#   'budget': 15000000,
#   'genres': ['Biography', 'Crime', 'Drama'],
#   'title': 'BlacKkKlansman'},
#  '/release/rl3540026881/?ref_=bo_yld_table_63': {'domestic': 63859435,
#   'international': 131473877,
#   'worldwide': 195333312,
#   'budget': None,
#   'genres': ['Adventure', 'Drama', 'Fantasy', 'Romance', 'Thriller'],
#   'title': 'The Shape of Water'},
#  '/release/rl2138998273/?ref_=bo_yld_table_64': {'domestic': 46874505,
#   'international': 104698129,
#   'worldwide': 151572634,
#   'budget': 69000000,
#   'genres': ['Action', 'Drama', 'Thriller'],
#   'title': 'Red Sparrow'},
#  '/release/rl1392870913/?ref_=bo_yld_table_65': {'domestic': 46840590,
#   'international': 4571030,
#   'worldwide': 51411620,
#   'budget': 6000000,
#   'genres': ['Action', 'Crime', 'Drama', 'Thriller'],
#   'title': 'Breaking In'},
#  '/release/rl654345729/?ref_=bo_yld_table_66': {'domestic': 46700633,
#   'international': 46619747,
#   'worldwide': 93320380,
#   'budget': 35000000,
#   'genres': ['Adventure', 'Comedy', 'Family', 'Fantasy', 'Horror'],
#   'title': 'Goosebumps 2: Haunted Halloween'},
#  '/release/rl2701166081/?ref_=bo_yld_table_67': {'domestic': 45819713,
#   'international': 21631102,
#   'worldwide': 67450815,
#   'budget': None,
#   'genres': ['Action', 'Drama', 'History', 'War'],
#   'title': '12 Strong'},
#  '/release/rl3154150913/?ref_=bo_yld_table_68': {'domestic': 44947622,
#   'international': 35562000,
#   'worldwide': 80509622,
#   'budget': None,
#   'genres': ['Action', 'Crime', 'Drama', 'Mystery', 'Thriller'],
#   'title': 'Den of Thieves'},
#  '/release/rl1107330561/?ref_=bo_yld_table_69': {'domestic': 44936545,
#   'international': 60760870,
#   'worldwide': 105697415,
#   'budget': 59000000,
#   'genres': ['Biography', 'Drama', 'History'],
#   'title': 'First Man'},
#  '/release/rl3892479489/?ref_=bo_yld_table_70': {'domestic': 44069456,
#   'international': 36131480,
#   'worldwide': 80200936,
#   'budget': None,
#   'genres': ['Drama', 'Horror', 'Mystery', 'Thriller'],
#   'title': 'Hereditary'},
#  '/release/rl2869134849/?ref_=bo_yld_table_71': {'domestic': 43549096,
#   'international': 2854573,
#   'worldwide': 46403669,
#   'budget': None,
#   'genres': ['Drama', 'Romance', 'Thriller'],
#   'title': "Tyler Perry's Acrimony"},
#  '/release/rl2809955841/?ref_=bo_yld_table_72': {'domestic': 43242871,
#   'international': 47254907,
#   'worldwide': 90497778,
#   'budget': 59000000,
#   'genres': ['Adventure',
#    'Animation',
#    'Comedy',
#    'Family',
#    'Fantasy',
#    'Mystery',
#    'Romance'],
#   'title': 'Sherlock Gnomes'},
#  '/release/rl67274241/?ref_=bo_yld_table_73': {'domestic': 42469946,
#   'international': 4194468,
#   'worldwide': 46664414,
#   'budget': None,
#   'genres': ['Comedy', 'Sport'],
#   'title': 'Uncle Drew'},
#  '/release/rl3355477505/?ref_=bo_yld_table_74': {'domestic': 42402632,
#   'international': 33582068,
#   'worldwide': 75984700,
#   'budget': 42000000,
#   'genres': ['Crime', 'Drama', 'Thriller'],
#   'title': 'Widows'},
#  '/release/rl343770625/?ref_=bo_yld_table_75': {'domestic': 104897530,
#   'international': 80502815,
#   'worldwide': 185400345,
#   'budget': 45000000,
#   'genres': ['Comedy', 'Music'],
#   'title': 'Pitch Perfect 3'},
#  '/release/rl3355608577/?ref_=bo_yld_table_76': {'domestic': 41411015,
#   'international': 53919478,
#   'worldwide': 95330493,
#   'budget': 3500000,
#   'genres': ['Horror', 'Thriller'],
#   'title': 'Truth or Dare'},
#  '/release/rl1577289217/?ref_=bo_yld_table_77': {'domestic': 40891591,
#   'international': 187086932,
#   'worldwide': 227978523,
#   'budget': None,
#   'genres': ['Adventure', 'Comedy', 'Family', 'Fantasy'],
#   'title': 'Paddington 2'},
#  '/release/rl2768274945/?ref_=bo_yld_table_78': {'domestic': 40826341,
#   'international': 25489948,
#   'worldwide': 66316289,
#   'budget': 17000000,
#   'genres': ['Comedy', 'Drama', 'Romance'],
#   'title': 'Love, Simon'},
#  '/release/rl570525185/?ref_=bo_yld_table_79': {'domestic': 56468410,
#   'international': 94378797,
#   'worldwide': 150847207,
#   'budget': None,
#   'genres': ['Biography', 'Drama', 'History', 'Thriller', 'War'],
#   'title': 'Darkest Hour'},
#  '/release/rl2155775489/?ref_=bo_yld_table_80': {'domestic': 36343858,
#   'international': 83598529,
#   'worldwide': 119942387,
#   'budget': None,
#   'genres': ['Action', 'Mystery', 'Thriller'],
#   'title': 'The Commuter'},
#  '/release/rl604210689/?ref_=bo_yld_table_81': {'domestic': 36276286,
#   'international': 20800000,
#   'worldwide': 57076286,
#   'budget': 30000000,
#   'genres': ['Biography', 'Drama', 'Thriller'],
#   'title': 'The 15:17 to Paris'},
#  '/release/rl1761969665/?ref_=bo_yld_table_82': {'domestic': 36108758,
#   'international': 30200000,
#   'worldwide': 66308758,
#   'budget': 50000000,
#   'genres': ['Action', 'Thriller'],
#   'title': 'Mile 22'},
#  '/release/rl3699344897/?ref_=bo_yld_table_83': {'domestic': 35857181,
#   'international': 62346015,
#   'worldwide': 98203196,
#   'budget': 51000000,
#   'genres': ['Action', 'Adventure', 'Drama', 'Family'],
#   'title': 'Alpha'},
#  '/release/rl738493953/?ref_=bo_yld_table_84': {'domestic': 35418723,
#   'international': 18500000,
#   'worldwide': 53918723,
#   'budget': 25000000,
#   'genres': ['Action', 'Drama', 'Thriller'],
#   'title': 'Peppermint'},
#  '/release/rl33719809/?ref_=bo_yld_table_85': {'domestic': 34017028,
#   'international': 15545682,
#   'worldwide': 49562710,
#   'budget': 30000000,
#   'genres': ['Action', 'Crime', 'Drama', 'Thriller'],
#   'title': 'Death Wish'},
#  '/release/rl872646145/?ref_=bo_yld_table_86': {'domestic': 33562069,
#   'international': 41758611,
#   'worldwide': 75320680,
#   'budget': 40000000,
#   'genres': ['Action', 'Adventure', 'Comedy'],
#   'title': 'The Spy Who Dumped Me'},
#  '/release/rl1057129985/?ref_=bo_yld_table_87': {'domestic': 32732301,
#   'international': 10338614,
#   'worldwide': 43070915,
#   'budget': 40000000,
#   'genres': ['Adventure', 'Drama', 'Horror', 'Mystery', 'Sci-Fi', 'Thriller'],
#   'title': 'Annihilation'},
#  '/release/rl805799425/?ref_=bo_yld_table_88': {'domestic': 85080171,
#   'international': 236672485,
#   'worldwide': 321752656,
#   'budget': 23000000,
#   'genres': ['Biography', 'Comedy', 'Drama', 'Music'],
#   'title': 'Green Book'},
#  '/release/rl3288368641/?ref_=bo_yld_table_89': {'domestic': 32015231,
#   'international': 32226268,
#   'worldwide': 64241499,
#   'budget': None,
#   'genres': ['Adventure', 'Animation', 'Comedy', 'Drama', 'Fantasy', 'Sci-Fi'],
#   'title': 'Isle of Dogs'},
#  '/release/rl3791816193/?ref_=bo_yld_table_90': {'domestic': 31713110,
#   'international': 1992223,
#   'worldwide': 33705333,
#   'budget': 19000000,
#   'genres': ['Comedy', 'Drama', 'Romance'],
#   'title': "Nobody's Fool"},
#  '/release/rl1157989889/?ref_=bo_yld_table_91': {'domestic': 31445012,
#   'international': 28500000,
#   'worldwide': 59945012,
#   'budget': 35000000,
#   'genres': ['Action',
#    'Adventure',
#    'Biography',
#    'Drama',
#    'Romance',
#    'Thriller'],
#   'title': 'Adrift'},
#  '/release/rl1968408065/?ref_=bo_yld_table_92': {'domestic': 84410380,
#   'international': 211658819,
#   'worldwide': 296069199,
#   'budget': 111000000,
#   'genres': ['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy'],
#   'title': 'Ferdinand'},
#  '/release/rl2147583489/?ref_=bo_yld_table_93': {'domestic': 30824628,
#   'international': 55664403,
#   'worldwide': 86489031,
#   'budget': 100000000,
#   'genres': ['Action', 'Adventure', 'Drama', 'Thriller'],
#   'title': 'Robin Hood'},
#  '/release/rl436372993/?ref_=bo_yld_table_94': {'domestic': 30617396,
#   'international': 1008990,
#   'worldwide': 31626386,
#   'budget': 13500000,
#   'genres': ['Comedy', 'Crime', 'Mystery'],
#   'title': 'Super Troopers 2'},
#  '/release/rl3573646849/?ref_=bo_yld_table_95': {'domestic': 30569484,
#   'international': 21169065,
#   'worldwide': 51738549,
#   'budget': 10000000,
#   'genres': ['Horror', 'Mystery', 'Thriller'],
#   'title': 'Slender Man'},
#  '/release/rl4278224385/?ref_=bo_yld_table_96': {'domestic': 54513740,
#   'international': 105678291,
#   'worldwide': 160192031,
#   'budget': None,
#   'genres': ['Comedy', 'Crime', 'Drama'],
#   'title': 'Three Billboards Outside Ebbing, Missouri'},
#  '/release/rl3983050241/?ref_=bo_yld_table_97': {'domestic': 209726015,
#   'international': 597356181,
#   'worldwide': 807082196,
#   'budget': None,
#   'genres': ['Adventure',
#    'Animation',
#    'Family',
#    'Fantasy',
#    'Music',
#    'Mystery'],
#   'title': 'Coco'},
#  '/release/rl3875767809/?ref_=bo_yld_table_98': {'domestic': 29790236,
#   'international': 22300000,
#   'worldwide': 52090236,
#   'budget': 10000000,
#   'genres': ['Action',
#    'Adventure',
#    'Animation',
#    'Comedy',
#    'Family',
#    'Fantasy',
#    'Musical',
#    'Sci-Fi'],
#   'title': 'Teen Titans GO! To the Movies'},
#  '/release/rl2265089537/?ref_=bo_yld_table_99': {'domestic': 29819114,
#   'international': 5849903,
#   'worldwide': 35669017,
#   'budget': None,
#   'genres': ['Drama', 'Western'],
#   'title': 'Hostiles'},
#  '/release/rl4026828289/?ref_=bo_yld_table_100': {'domestic': 29719483,
#   'international': 5214526,
#   'worldwide': 34934009,
#   'budget': 23000000,
#   'genres': ['Crime', 'Drama'],
#   'title': 'The Hate U Give'},
#  '/release/rl1141016065/?ref_=bo_yld_table_101': {'domestic': 30014539,
#   'international': 23924758,
#   'worldwide': 53939297,
#   'budget': None,
#   'genres': ['Biography', 'Comedy', 'Drama', 'Sport'],
#   'title': 'I, Tonya'},
#  '/release/rl369395201/?ref_=bo_yld_table_102': {'domestic': 26020957,
#   'international': 49441080,
#   'worldwide': 75462037,
#   'budget': None,
#   'genres': ['Drama', 'Mystery', 'Thriller'],
#   'title': 'Searching'},
#  '/release/rl117671425/?ref_=bo_yld_table_103': {'domestic': 25091816,
#   'international': 18927772,
#   'worldwide': 44019588,
#   'budget': None,
#   'genres': ['Biography', 'Drama', 'Fantasy', 'Horror', 'Mystery', 'Thriller'],
#   'title': 'Winchester'},
#  '/release/rl4236019201/?ref_=bo_yld_table_104': {'domestic': 24586708,
#   'international': 6452418,
#   'worldwide': 31039126,
#   'budget': None,
#   'genres': ['Horror'],
#   'title': 'The Strangers: Prey at Night'},
#  '/release/rl2013300225/?ref_=bo_yld_table_105': {'domestic': 24011188,
#   'international': 1946294,
#   'worldwide': 25957482,
#   'budget': 29000000,
#   'genres': ['Crime', 'Drama'],
#   'title': 'White Boy Rick'},
#  '/release/rl4194665985/?ref_=bo_yld_table_106': {'domestic': 39282227,
#   'international': 33000000,
#   'worldwide': 72282227,
#   'budget': 16000000,
#   'genres': ['Comedy', 'Drama', 'Romance'],
#   'title': 'Second Act'},
#  '/release/rl2416150017/?ref_=bo_yld_table_107': {'domestic': 28780744,
#   'international': 30503271,
#   'worldwide': 59284015,
#   'budget': None,
#   'genres': ['Biography', 'Crime', 'Drama'],
#   'title': "Molly's Game"},
#  '/release/rl688227841/?ref_=bo_yld_table_108': {'domestic': 22835787,
#   'international': 8954,
#   'worldwide': 22844741,
#   'budget': None,
#   'genres': ['Biography', 'Documentary'],
#   'title': "Won't You Be My Neighbor?"},
#  '/release/rl2953020929/?ref_=bo_yld_table_109': {'domestic': 21704844,
#   'international': 19953000,
#   'worldwide': 41657844,
#   'budget': 38000000,
#   'genres': ['Action', 'Adventure', 'Horror', 'Mystery', 'Sci-Fi', 'War'],
#   'title': 'Overlord'},
#  '/release/rl2130740737/?ref_=bo_yld_table_110': {'domestic': 30573626,
#   'international': 9893344,
#   'worldwide': 40466970,
#   'budget': 42000000,
#   'genres': ['Comedy', 'Crime', 'Mystery'],
#   'title': 'Holmes & Watson'},
#  '/release/rl2113963521/?ref_=bo_yld_table_111': {'domestic': 20877013,
#   'international': 876352,
#   'worldwide': 21753365,
#   'budget': 14000000,
#   'genres': ['Action', 'Crime', 'Drama', 'Thriller'],
#   'title': 'Proud Mary'},
#  '/release/rl2432927233/?ref_=bo_yld_table_112': {'domestic': 20706452,
#   'international': 6800000,
#   'worldwide': 27506452,
#   'budget': 40000000,
#   'genres': ['Action', 'Comedy', 'Crime', 'Fantasy', 'Mystery', 'Thriller'],
#   'title': 'The Happytime Murders'},
#  '/release/rl587433473/?ref_=bo_yld_table_113': {'domestic': 21198205,
#   'international': 26558385,
#   'worldwide': 47756590,
#   'budget': None,
#   'genres': ['Drama', 'Romance'],
#   'title': 'Phantom Thread'},
#  '/release/rl1124435457/?ref_=bo_yld_table_114': {'domestic': 20545116,
#   'international': 235569,
#   'worldwide': 20780685,
#   'budget': 16000000,
#   'genres': ['Action', 'Crime', 'Thriller'],
#   'title': 'SuperFly'},
#  '/release/rl1409779201/?ref_=bo_yld_table_115': {'domestic': 47836282,
#   'international': 28237206,
#   'worldwide': 76073488,
#   'budget': None,
#   'genres': ['Biography', 'Comedy', 'Drama'],
#   'title': 'Vice'},
#  '/release/rl3125577217/?ref_=bo_yld_table_116': {'domestic': 17857020,
#   'international': 21299834,
#   'worldwide': 39156854,
#   'budget': None,
#   'genres': ['Adventure', 'Comedy', 'Family'],
#   'title': 'Show Dogs'},
#  '/release/rl2449704449/?ref_=bo_yld_table_117': {'domestic': 17839115,
#   'international': 14043609,
#   'worldwide': 31882724,
#   'budget': 32000000,
#   'genres': ['Crime', 'Drama', 'Mystery', 'Thriller'],
#   'title': 'Bad Times at the El Royale'},
#  '/release/rl3204810241/?ref_=bo_yld_table_118': {'domestic': 17612099,
#   'international': None,
#   'worldwide': 17612099,
#   'budget': 24000000,
#   'genres': ['Biography', 'Drama', 'History', 'Thriller', 'War'],
#   'title': 'Operation Finale'},
#  '/release/rl1275233793/?ref_=bo_yld_table_119': {'domestic': 17560475,
#   'international': 8355491,
#   'worldwide': 25915966,
#   'budget': 5000000,
#   'genres': ['Adventure', 'Biography', 'Drama', 'History'],
#   'title': 'Paul, Apostle of Christ'},
#  '/release/rl1023575553/?ref_=bo_yld_table_120': {'domestic': 48958273,
#   'international': 30007338,
#   'worldwide': 78965611,
#   'budget': None,
#   'genres': ['Comedy', 'Drama'],
#   'title': 'Lady Bird'},
#  '/release/rl805602817/?ref_=bo_yld_table_121': {'domestic': 17493096,
#   'international': 677611,
#   'worldwide': 18170707,
#   'budget': None,
#   'genres': ['Comedy', 'Fantasy', 'Sci-Fi'],
#   'title': 'Sorry to Bother You'},
#  '/release/rl1493337601/?ref_=bo_yld_table_122': {'domestic': 17395520,
#   'international': 867950,
#   'worldwide': 18263470,
#   'budget': None,
#   'genres': ['Drama', 'History', 'Thriller'],
#   'title': 'Chappaquiddick'},
#  '/release/rl3271591425/?ref_=bo_yld_table_123': {'domestic': 16376066,
#   'international': None,
#   'worldwide': 16376066,
#   'budget': 3500000,
#   'genres': ['Drama', 'Music', 'Romance'],
#   'title': 'Forever My Girl'},
#  '/release/rl1325696513/?ref_=bo_yld_table_124': {'domestic': 34366783,
#   'international': 61551923,
#   'worldwide': 95918706,
#   'budget': None,
#   'genres': ['Biography', 'Comedy', 'Drama', 'History'],
#   'title': 'The Favourite'},
#  '/release/rl3931670017/?ref_=bo_yld_table_125': {'domestic': 15767460,
#   'international': 15905218,
#   'worldwide': 31672678,
#   'budget': 40000000,
#   'genres': ['Action', 'Thriller'],
#   'title': 'Hunter Killer'},
#  '/release/rl4278289921/?ref_=bo_yld_table_126': {'domestic': 15951040,
#   'international': 67721633,
#   'worldwide': 83672673,
#   'budget': None,
#   'genres': ['Action', 'Adventure', 'Fantasy', 'Sci-Fi', 'Thriller'],
#   'title': 'Mortal Engines'},
#  '/release/rl2986378753/?ref_=bo_yld_table_127': {'domestic': 14841338,
#   'international': 20323582,
#   'worldwide': 35164920,
#   'budget': 43000000,
#   'genres': ['Action', 'Crime', 'Drama', 'Thriller'],
#   'title': "The Girl in the Spider's Web"},
#  '/release/rl3556869633/?ref_=bo_yld_table_128': {'domestic': 14837422,
#   'international': 28179106,
#   'worldwide': 43016528,
#   'budget': 7700000,
#   'genres': ['Horror', 'Mystery', 'Thriller'],
#   'title': 'The Possession of Hannah Grace'},
#  '/release/rl117736961/?ref_=bo_yld_table_129': {'domestic': 14017361,
#   'international': 423931,
#   'worldwide': 14441292,
#   'budget': None,
#   'genres': ['Biography', 'Documentary'],
#   'title': 'RBG'},
#  '/release/rl3255076353/?ref_=bo_yld_table_130': {'domestic': 13539709,
#   'international': 807724,
#   'worldwide': 14347433,
#   'budget': None,
#   'genres': ['Comedy', 'Drama'],
#   'title': 'Eighth Grade'},
#  '/release/rl3087042049/?ref_=bo_yld_table_131': {'domestic': 18095701,
#   'international': 23791894,
#   'worldwide': 41887595,
#   'budget': None,
#   'genres': ['Drama', 'Romance'],
#   'title': 'Call Me by Your Name'},
#  '/release/rl2785052161/?ref_=bo_yld_table_132': {'domestic': 12695691,
#   'international': 28446688,
#   'worldwide': 41142379,
#   'budget': 34000000,
#   'genres': ['Action', 'Adventure', 'Drama', 'Romance', 'Sci-Fi', 'Thriller'],
#   'title': 'The Darkest Minds'},
#  '/release/rl3775104513/?ref_=bo_yld_table_133': {'domestic': 25113707,
#   'international': 31882597,
#   'worldwide': 56996304,
#   'budget': None,
#   'genres': ['Biography', 'Crime', 'Drama', 'Mystery', 'Thriller'],
#   'title': 'All the Money in the World'},
#  '/release/rl1678018049/?ref_=bo_yld_table_134': {'domestic': 12320845,
#   'international': 1127652,
#   'worldwide': 13448497,
#   'budget': None,
#   'genres': ['Biography', 'Documentary', 'Drama', 'History', 'Mystery'],
#   'title': 'Three Identical Strangers'},
#  '/release/rl1174767105/?ref_=bo_yld_table_135': {'domestic': 11977130,
#   'international': 4616424,
#   'worldwide': 16593554,
#   'budget': None,
#   'genres': ['Action', 'Sci-Fi', 'Thriller'],
#   'title': 'Upgrade'},
#  '/release/rl1191544321/?ref_=bo_yld_table_136': {'domestic': 11846060,
#   'international': 11145000,
#   'worldwide': 22991060,
#   'budget': None,
#   'genres': ['Drama', 'History', 'Romance', 'War'],
#   'title': 'Padmaavat'},
#  '/release/rl2164753921/?ref_=bo_yld_table_137': {'domestic': 17541090,
#   'international': 11777771,
#   'worldwide': 29318861,
#   'budget': None,
#   'genres': ['Adventure', 'Documentary', 'Sport'],
#   'title': 'Free Solo'},
#  '/release/rl1292142081/?ref_=bo_yld_table_138': {'domestic': 11277120,
#   'international': 6583277,
#   'worldwide': 17860397,
#   'budget': None,
#   'genres': ['Biography', 'Comedy', 'Crime', 'Drama', 'Romance'],
#   'title': 'The Old Man & the Gun'},
#  '/release/rl50497025/?ref_=bo_yld_table_139': {'domestic': 11107431,
#   'international': 7052260,
#   'worldwide': 18159691,
#   'budget': 5500000,
#   'genres': ['Horror', 'Thriller'],
#   'title': 'Hell Fest'},
#  '/release/rl1719567873/?ref_=bo_yld_table_140': {'domestic': 132422809,
#   'international': 173514909,
#   'worldwide': 305937718,
#   'budget': None,
#   'genres': ['Drama', 'Family'],
#   'title': 'Wonder'},
#  '/release/rl4228220417/?ref_=bo_yld_table_141': {'domestic': 10230620,
#   'international': None,
#   'worldwide': 10230620,
#   'budget': None,
#   'genres': ['Drama', 'Sport'],
#   'title': 'The Miracle Season'},
#  '/release/rl3171059201/?ref_=bo_yld_table_142': {'domestic': 16468499,
#   'international': 30244310,
#   'worldwide': 46712809,
#   'budget': None,
#   'genres': ['Biography', 'Drama', 'History'],
#   'title': 'Mary Queen of Scots'},
#  '/release/rl1459717633/?ref_=bo_yld_table_143': {'domestic': 9561064,
#   'international': 17804403,
#   'worldwide': 27365467,
#   'budget': None,
#   'genres': ['Drama', 'Romance'],
#   'title': 'Midnight Sun'},
#  '/release/rl620987905/?ref_=bo_yld_table_144': {'domestic': 9369755,
#   'international': 6266707,
#   'worldwide': 15636462,
#   'budget': None,
#   'genres': ['Comedy', 'Drama', 'Mystery'],
#   'title': 'Tully'},
#  '/release/rl235046401/?ref_=bo_yld_table_145': {'domestic': 9186156,
#   'international': 329758,
#   'worldwide': 9515914,
#   'budget': None,
#   'genres': ['Action', 'Crime', 'Drama', 'Thriller'],
#   'title': 'Traffik'},
#  '/release/rl2432992769/?ref_=bo_yld_table_146': {'domestic': 8866745,
#   'international': 7158242,
#   'worldwide': 16024987,
#   'budget': 1000000,
#   'genres': ['Horror', 'Mystery', 'Thriller'],
#   'title': 'Unfriended: Dark Web'},
#  '/release/rl2264958465/?ref_=bo_yld_table_147': {'domestic': 10763520,
#   'international': 2297971,
#   'worldwide': 13061491,
#   'budget': None,
#   'genres': ['Biography', 'Comedy', 'Drama', 'Fantasy', 'Romance'],
#   'title': 'Welcome to Marwen'},
#  '/release/rl2835580417/?ref_=bo_yld_table_148': {'domestic': 8267544,
#   'international': 46355270,
#   'worldwide': 54622814,
#   'budget': None,
#   'genres': ['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy', 'Sport'],
#   'title': 'Early Man'},
#  '/release/rl3825567233/?ref_=bo_yld_table_149': {'domestic': 9601092,
#   'international': 10377097,
#   'worldwide': 19978189,
#   'budget': None,
#   'genres': ['Drama'],
#   'title': 'The Wife'},
#  '/release/rl4093806081/?ref_=bo_yld_table_150': {'domestic': 8047856,
#   'international': 16598199,
#   'worldwide': 24646055,
#   'budget': None,
#   'genres': ['Comedy', 'Drama', 'History'],
#   'title': 'The Death of Stalin'},
#  '/release/rl184976897/?ref_=bo_yld_table_151': {'domestic': 17956913,
#   'international': 1173098,
#   'worldwide': 19130011,
#   'budget': None,
#   'genres': ['Documentary', 'History', 'War'],
#   'title': 'They Shall Not Grow Old'},
#  '/release/rl3137635841/?ref_=bo_yld_table_152': {'domestic': 7909317,
#   'international': 68783735,
#   'worldwide': 76693052,
#   'budget': None,
#   'genres': ['Biography', 'Drama'],
#   'title': 'Sanju'},
#  '/release/rl3456271873/?ref_=bo_yld_table_153': {'domestic': 7732899,
#   'international': 6560702,
#   'worldwide': 14293601,
#   'budget': None,
#   'genres': ['Drama', 'Horror', 'Mystery', 'Thriller'],
#   'title': 'Unsane'},
#  '/release/rl1023706625/?ref_=bo_yld_table_154': {'domestic': 7649973,
#   'international': 8986631,
#   'worldwide': 16636604,
#   'budget': None,
#   'genres': ['Biography', 'Drama'],
#   'title': 'Beautiful Boy'},
#  '/release/rl50693633/?ref_=bo_yld_table_155': {'domestic': 8803865,
#   'international': 3638296,
#   'worldwide': 12442161,
#   'budget': None,
#   'genres': ['Biography', 'Comedy', 'Crime', 'Drama'],
#   'title': 'Can You Ever Forgive Me?'},
#  '/release/rl1845986817/?ref_=bo_yld_table_156': {'domestic': 7362439,
#   'international': 1940583,
#   'worldwide': 9303022,
#   'budget': None,
#   'genres': ['Comedy', 'Drama'],
#   'title': 'Mid90s'},
#  '/release/rl628917761/?ref_=bo_yld_table_157': {'domestic': 24449754,
#   'international': 30554136,
#   'worldwide': 55003890,
#   'budget': 68000000,
#   'genres': ['Drama', 'Sci-Fi'],
#   'title': 'Downsizing'},
#  '/release/rl3137701377/?ref_=bo_yld_table_158': {'domestic': 6809080,
#   'international': 33276,
#   'worldwide': 6842356,
#   'budget': None,
#   'genres': ['Comedy', 'Drama', 'Romance'],
#   'title': 'Dog Days'},
#  '/release/rl3154281985/?ref_=bo_yld_table_159': {'domestic': 6788692,
#   'international': 5064389,
#   'worldwide': 11853081,
#   'budget': None,
#   'genres': ['Biography', 'Drama'],
#   'title': 'Boy Erased'},
#  '/release/rl2583987713/?ref_=bo_yld_table_160': {'domestic': 6708147,
#   'international': 6605434,
#   'worldwide': 13313581,
#   'budget': None,
#   'genres': ['Action', 'Crime', 'Drama', 'Sci-Fi', 'Thriller'],
#   'title': 'Hotel Artemis'},
#  '/release/rl1912899073/?ref_=bo_yld_table_161': {'domestic': 6501381,
#   'international': 1966316,
#   'worldwide': 8467697,
#   'budget': None,
#   'genres': ['Action', 'Adventure', 'Family', 'Sci-Fi', 'Thriller'],
#   'title': 'A-X-L'},
#  '/release/rl17270273/?ref_=bo_yld_table_162': {'domestic': 6352306,
#   'international': 321862,
#   'worldwide': 6674168,
#   'budget': None,
#   'genres': ['Documentary'],
#   'title': 'Fahrenheit 11/9'},
#  '/release/rl4026893825/?ref_=bo_yld_table_163': {'domestic': 6216897,
#   'international': None,
#   'worldwide': 6216897,
#   'budget': None,
#   'genres': ['Biography', 'Drama', 'History'],
#   'title': 'Unbroken: Path to Redemption'},
#  '/release/rl1510114817/?ref_=bo_yld_table_164': {'domestic': 6115825,
#   'international': 26401423,
#   'worldwide': 32517248,
#   'budget': 35000000,
#   'genres': ['Action', 'Adventure', 'Crime', 'Thriller'],
#   'title': 'The Hurricane Heist'},
#  '/release/rl1812301313/?ref_=bo_yld_table_165': {'domestic': 6102076,
#   'international': 4319771,
#   'worldwide': 10421847,
#   'budget': 4900000,
#   'genres': ['Drama', 'Fantasy', 'Romance'],
#   'title': 'Every Day'},
#  '/release/rl4060448257/?ref_=bo_yld_table_166': {'domestic': 6046104,
#   'international': 1636824,
#   'worldwide': 7682928,
#   'budget': None,
#   'genres': ['Drama'],
#   'title': 'Leave No Trace'},
#  '/release/rl4110910977/?ref_=bo_yld_table_167': {'domestic': 6100309,
#   'international': 45147259,
#   'worldwide': 51247568,
#   'budget': 110000000,
#   'genres': ['Action', 'Adventure', 'Comedy', 'Sci-Fi'],
#   'title': 'Once Upon a Deadpool'},
#  '/release/rl3506734593/?ref_=bo_yld_table_168': {'domestic': 5885881,
#   'international': None,
#   'worldwide': 5885881,
#   'budget': 6000000,
#   'genres': ['Documentary', 'History'],
#   'title': 'Death of a Nation'},
#  '/release/rl2114225665/?ref_=bo_yld_table_169': {'domestic': 7574012,
#   'international': 61766,
#   'worldwide': 7635778,
#   'budget': None,
#   'genres': ['Documentary'],
#   'title': 'Pandas'},
#  '/release/rl4027024897/?ref_=bo_yld_table_170': {'domestic': 5754556,
#   'international': 15268168,
#   'worldwide': 21022724,
#   'budget': None,
#   'genres': ['Action',
#    'Adventure',
#    'Animation',
#    'Comedy',
#    'Family',
#    'Fantasy',
#    'Sci-Fi'],
#   'title': 'My Hero Academia: Two Heroes'},
#  '/release/rl1325434369/?ref_=bo_yld_table_171': {'domestic': 5728940,
#   'international': 1685238,
#   'worldwide': 7414178,
#   'budget': None,
#   'genres': ['Drama'],
#   'title': "God's Not Dead: A Light in Darkness"},
#  '/release/rl637896193/?ref_=bo_yld_table_172': {'domestic': 5718096,
#   'international': 4594923,
#   'worldwide': 10313019,
#   'budget': None,
#   'genres': ['Action', 'Adventure', 'Crime', 'Drama', 'Sci-Fi', 'Thriller'],
#   'title': 'Kin'},
#  '/release/rl4110779905/?ref_=bo_yld_table_173': {'domestic': 5137622,
#   'international': 9135411,
#   'worldwide': 14273033,
#   'budget': None,
#   'genres': ['Biography', 'Drama', 'History', 'Romance'],
#   'title': 'Colette'},
#  '/release/rl2382398977/?ref_=bo_yld_table_174': {'domestic': 5059608,
#   'international': 44055,
#   'worldwide': 5103663,
#   'budget': 19000000,
#   'genres': ['Comedy'],
#   'title': 'Action Point'},
#  '/release/rl3942811137/?ref_=bo_yld_table_175': {'domestic': 5019226,
#   'international': 2490210,
#   'worldwide': 7509436,
#   'budget': None,
#   'genres': ['Action', 'Drama', 'Thriller'],
#   'title': 'Beirut'},
#  '/release/rl3489760769/?ref_=bo_yld_table_176': {'domestic': 4969853,
#   'international': 6031774,
#   'worldwide': 11001627,
#   'budget': None,
#   'genres': ['Action', 'Comedy', 'Crime', 'Drama'],
#   'title': 'Gringo'},
#  '/release/rl1174439425/?ref_=bo_yld_table_177': {'domestic': 4719928,
#   'international': 153897,
#   'worldwide': 4873825,
#   'budget': None,
#   'genres': ['Action', 'Drama'],
#   'title': 'Samson'},
#  '/release/rl3246228993/?ref_=bo_yld_table_178': {'domestic': 17501244,
#   'international': 8100000,
#   'worldwide': 25601244,
#   'budget': None,
#   'genres': ['Comedy', 'Drama'],
#   'title': 'Father Figures'},
#  '/release/rl1845855745/?ref_=bo_yld_table_179': {'domestic': 4412170,
#   'international': 154558606,
#   'worldwide': 158970776,
#   'budget': 25000000,
#   'genres': ['Action', 'Adventure', 'Comedy'],
#   'title': 'Johnny English Strikes Again'},
#  '/release/rl3892610561/?ref_=bo_yld_table_180': {'domestic': 4343227,
#   'international': 2069122,
#   'worldwide': 6412349,
#   'budget': None,
#   'genres': ['Biography', 'Crime', 'Drama'],
#   'title': 'Gotti'},
#  '/release/rl2600830465/?ref_=bo_yld_table_181': {'domestic': 4333394,
#   'international': 673595,
#   'worldwide': 5006989,
#   'budget': None,
#   'genres': ['Comedy', 'Crime', 'Drama'],
#   'title': 'Blindspotting'},
#  '/release/rl101090817/?ref_=bo_yld_table_182': {'domestic': 4201819,
#   'international': 16145694,
#   'worldwide': 20347513,
#   'budget': None,
#   'genres': ['Documentary', 'Music'],
#   'title': 'Burn the Stage: The Movie'},
#  '/release/rl3842278913/?ref_=bo_yld_table_183': {'domestic': 4165949,
#   'international': 9968774,
#   'worldwide': 14134723,
#   'budget': None,
#   'genres': ['Drama'],
#   'title': 'Ya veremos'},
#  '/release/rl688162305/?ref_=bo_yld_table_184': {'domestic': 4102648,
#   'international': 3895126,
#   'worldwide': 7997774,
#   'budget': None,
#   'genres': ['Drama', 'Romance'],
#   'title': 'Life Itself'},
#  '/release/rl687900161/?ref_=bo_yld_table_185': {'domestic': 4015935,
#   'international': 916759,
#   'worldwide': 4932694,
#   'budget': None,
#   'genres': ['Adventure', 'Animation', 'Family', 'History', 'War'],
#   'title': 'Sgt. Stubby: An American Hero'},
#  '/release/rl2959312385/?ref_=bo_yld_table_186': {'domestic': 315058289,
#   'international': 538918837,
#   'worldwide': 853977126,
#   'budget': 180000000,
#   'genres': ['Action', 'Adventure', 'Comedy', 'Fantasy', 'Sci-Fi'],
#   'title': 'Thor: Ragnarok'},
#  '/release/rl1074234881/?ref_=bo_yld_table_187': {'domestic': 3679893,
#   'international': None,
#   'worldwide': 3679893,
#   'budget': None,
#   'genres': ['Crime', 'Drama'],
#   'title': "Gosnell: The Trial of America's Biggest Serial Killer"},
#  '/release/rl0296449/?ref_=bo_yld_table_188': {'domestic': 3511417,
#   'international': 78216,
#   'worldwide': 3589633,
#   'budget': None,
#   'genres': ['Drama', 'War'],
#   'title': 'Indivisible'},
#  '/release/rl3020260865/?ref_=bo_yld_table_189': {'domestic': 3508777,
#   'international': 2346,
#   'worldwide': 3511123,
#   'budget': None,
#   'genres': ['Action', 'Drama'],
#   'title': 'The Oscar Nominated Short Films 2018: Live Action'},
#  '/release/rl3959588353/?ref_=bo_yld_table_190': {'domestic': 3498782,
#   'international': 4504398,
#   'worldwide': 8003180,
#   'budget': None,
#   'genres': ['Drama', 'Romance'],
#   'title': 'Disobedience'},
#  '/release/rl1129088513/?ref_=bo_yld_table_191': {'domestic': 229024295,
#   'international': 428900000,
#   'worldwide': 657924295,
#   'budget': None,
#   'genres': ['Action', 'Adventure', 'Fantasy', 'Sci-Fi'],
#   'title': 'Justice League'},
#  '/release/rl2147845633/?ref_=bo_yld_table_192': {'domestic': 3448256,
#   'international': 414242,
#   'worldwide': 3862498,
#   'budget': None,
#   'genres': ['Drama', 'Mystery', 'Thriller'],
#   'title': 'First Reformed'},
#  '/release/rl285509121/?ref_=bo_yld_table_193': {'domestic': 3444895,
#   'international': 1066262,
#   'worldwide': 4511157,
#   'budget': None,
#   'genres': ['Comedy', 'Drama', 'Music', 'Romance'],
#   'title': 'Juliet, Naked'},
#  '/release/rl2768602625/?ref_=bo_yld_table_194': {'domestic': 3435047,
#   'international': 1188789,
#   'worldwide': 4623836,
#   'budget': None,
#   'genres': ['Crime', 'Horror', 'Thriller'],
#   'title': 'Bad Samaritan'},
#  '/release/rl2298512897/?ref_=bo_yld_table_195': {'domestic': 3326885,
#   'international': 5444547,
#   'worldwide': 8771432,
#   'budget': None,
#   'genres': ['Action', 'Drama', 'History', 'Thriller'],
#   'title': '7 Days in Entebbe'},
#  '/release/rl1979942401/?ref_=bo_yld_table_196': {'domestic': 21120616,
#   'international': 8700000,
#   'worldwide': 29820616,
#   'budget': None,
#   'genres': ['Biography', 'Comedy', 'Drama'],
#   'title': 'The Disaster Artist'},
#  '/release/rl2214888961/?ref_=bo_yld_table_197': {'domestic': 3236321,
#   'international': 587129,
#   'worldwide': 3823450,
#   'budget': 12000000,
#   'genres': ['Adventure', 'Sci-Fi'],
#   'title': '2001: A Space Odyssey'},
#  '/release/rl1644594689/?ref_=bo_yld_table_198': {'domestic': 4152000,
#   'international': 32793969,
#   'worldwide': 36945969,
#   'budget': None,
#   'genres': ['Action', 'Sci-Fi'],
#   'title': '2.0'},
#  '/release/rl2164491777/?ref_=bo_yld_table_199': {'domestic': 3226443,
#   'international': 7245737,
#   'worldwide': 10472180,
#   'budget': None,
#   'genres': ['Adventure', 'Comedy', 'Drama', 'Romance'],
#   'title': 'The Leisure Seeker'},
#  '/release/rl1376224769/?ref_=bo_yld_table_200': {'domestic': 3143056,
#   'international': 10000000,
#   'worldwide': 13143056,
#   'budget': None,
#   'genres': ['Crime', 'Drama', 'Western'],
#   'title': 'The Sisters Brothers'},
#  '/release/rl2718074369/?ref_=bo_yld_table_201': {'domestic': 3072605,
#   'international': 114650,
#   'worldwide': 3187255,
#   'budget': None,
#   'genres': ['Comedy', 'Crime', 'Drama', 'Thriller'],
#   'title': 'Thoroughbreds'},
#  '/release/rl3926230529/?ref_=bo_yld_table_202': {'domestic': 3026351,
#   'international': 1578772,
#   'worldwide': 4605123,
#   'budget': None,
#   'genres': ['Biography', 'Documentary', 'Music'],
#   'title': 'Whitney'},
#  '/release/rl2449835521/?ref_=bo_yld_table_203': {'domestic': 2856954,
#   'international': 1223119,
#   'worldwide': 4080073,
#   'budget': None,
#   'genres': ['Biography', 'Crime', 'Drama', 'Thriller'],
#   'title': 'American Animals'},
#  '/release/rl3523511809/?ref_=bo_yld_table_204': {'domestic': 2846257,
#   'international': 1976,
#   'worldwide': 2848233,
#   'budget': None,
#   'genres': ['Drama', 'Family', 'Romance'],
#   'title': 'God Bless the Broken Road'},
#  '/release/rl1980073473/?ref_=bo_yld_table_205': {'domestic': 2783739,
#   'international': 8238055,
#   'worldwide': 11021794,
#   'budget': None,
#   'genres': ['Comedy', 'Romance'],
#   'title': 'La boda de Valentina'},
#  '/release/rl1090815489/?ref_=bo_yld_table_206': {'domestic': 2663090,
#   'international': 613167,
#   'worldwide': 3276257,
#   'budget': None,
#   'genres': ['Action', 'Drama'],
#   'title': 'Bharath Ane Nenu'},
#  '/release/rl2365949441/?ref_=bo_yld_table_207': {'domestic': 2528078,
#   'international': 6832436,
#   'worldwide': 9360514,
#   'budget': None,
#   'genres': ['Crime', 'Drama', 'Mystery', 'Thriller'],
#   'title': 'You Were Never Really Here'},
#  '/release/rl4252861953/?ref_=bo_yld_table_208': {'domestic': 15650615,
#   'international': 10079505,
#   'worldwide': 25730120,
#   'budget': None,
#   'genres': ['Documentary'],
#   'title': 'A Beautiful Planet'},
#  '/release/rl3238299137/?ref_=bo_yld_table_209': {'domestic': 2483472,
#   'international': 5458621,
#   'worldwide': 7942093,
#   'budget': None,
#   'genres': ['Fantasy', 'Horror', 'Mystery', 'Thriller'],
#   'title': 'Suspiria'},
#  '/release/rl923108865/?ref_=bo_yld_table_210': {'domestic': 2419031,
#   'international': 1015932,
#   'worldwide': 3434963,
#   'budget': None,
#   'genres': ['Drama', 'Western'],
#   'title': 'The Rider'},
#  '/release/rl1963296257/?ref_=bo_yld_table_211': {'domestic': 2418404,
#   'international': 39560027,
#   'worldwide': 41978431,
#   'budget': None,
#   'genres': ['Adventure', 'Animation', 'Family', 'Fantasy'],
#   'title': "Mary and the Witch's Flower"},
#  '/release/rl2634319361/?ref_=bo_yld_table_212': {'domestic': 2386251,
#   'international': 30914,
#   'worldwide': 2417165,
#   'budget': None,
#   'genres': ['Comedy', 'Drama', 'Music'],
# ...
#   'international': None,
#   'worldwide': 3895,
#   'budget': None,
#   'genres': ['Adventure'],
#   'title': 'American Dresser'},
#  '/release/rl1594000897/?ref_=bo_yld_table_916': {'domestic': 30157,
#   'international': 291611,
#   'worldwide': 321768,
#   'budget': None,
#   'genres': ['Drama', 'Thriller'],
#   'title': 'Nocturama'},
#  '/release/rl872777217/?ref_=bo_yld_table_917': {'domestic': 15126,
#   'international': 75723,
#   'worldwide': 90849,
#   'budget': None,
#   'genres': ['Drama', 'Romance'],
#   'title': 'Porto'},
#  '/release/rl1594328577/?ref_=bo_yld_table_918': {'domestic': 3815,
#   'international': 409,
#   'worldwide': 4224,
#   'budget': None,
#   'genres': ['Drama'],
#   'title': 'Cocote'},
#  '/release/rl0165377/?ref_=bo_yld_table_919': {'domestic': 12433,
#   'international': 253062,
#   'worldwide': 265495,
#   'budget': None,
#   'genres': ['Drama', 'Music'],
#   'title': 'Félicité'},
#  '/release/rl2416412161/?ref_=bo_yld_table_920': {'domestic': 3751,
#   'international': None,
#   'worldwide': 3751,
#   'budget': None,
#   'genres': ['Drama'],
#   'title': 'Nelly'},
#  '/release/rl319260161/?ref_=bo_yld_table_921': {'domestic': 3696,
#   'international': None,
#   'worldwide': 3696,
#   'budget': None,
#   'genres': ['Drama'],
#   'title': 'The Family'},
#  '/release/rl570787329/?ref_=bo_yld_table_922': {'domestic': 3550,
#   'international': None,
#   'worldwide': 3550,
#   'budget': None,
#   'genres': ['Comedy', 'Drama'],
#   'title': 'Fourplay'},
#  '/release/rl4026697217/?ref_=bo_yld_table_923': {'domestic': 32059,
#   'international': 3977,
#   'worldwide': 36036,
#   'budget': None,
#   'genres': ['Documentary'],
#   'title': 'Brimstone & Glory'},
#  '/release/rl369591809/?ref_=bo_yld_table_924': {'domestic': 3495,
#   'international': None,
#   'worldwide': 3495,
#   'budget': None,
#   'genres': ['Drama'],
#   'title': 'The Citizen'},
#  '/release/rl117868033/?ref_=bo_yld_table_925': {'domestic': 3429,
#   'international': 20468,
#   'worldwide': 23897,
#   'budget': None,
#   'genres': ['Documentary'],
#   'title': 'Under The Wire'},
#  '/release/rl1963230721/?ref_=bo_yld_table_926': {'domestic': 3350,
#   'international': None,
#   'worldwide': 3350,
#   'budget': None,
#   'genres': ['Thriller'],
#   'title': 'Followers'},
#  '/release/rl2802091521/?ref_=bo_yld_table_927': {'domestic': 3314,
#   'international': 12169,
#   'worldwide': 15483,
#   'budget': None,
#   'genres': ['Biography', 'Drama'],
#   'title': 'Tom of Finland'},
#  '/release/rl1526957569/?ref_=bo_yld_table_928': {'domestic': 16182,
#   'international': 5167,
#   'worldwide': 21349,
#   'budget': None,
#   'genres': ['Biography', 'Drama'],
#   'title': 'Song Of Granite'},
#  '/release/rl3506931201/?ref_=bo_yld_table_929': {'domestic': 3292,
#   'international': 23046,
#   'worldwide': 26338,
#   'budget': None,
#   'genres': ['Drama', 'Sci-Fi', 'Thriller'],
#   'title': 'At First Light'},
#  '/release/rl2047116801/?ref_=bo_yld_table_930': {'domestic': 3142,
#   'international': None,
#   'worldwide': 3142,
#   'budget': None,
#   'genres': ['Documentary'],
#   'title': 'Game Changers'},
#  '/release/rl3003614721/?ref_=bo_yld_table_931': {'domestic': 3133,
#   'international': None,
#   'worldwide': 3133,
#   'budget': None,
#   'genres': ['Documentary'],
#   'title': 'Hot to Trot'},
#  '/release/rl268928513/?ref_=bo_yld_table_932': {'domestic': 3243,
#   'international': None,
#   'worldwide': 3243,
#   'budget': None,
#   'genres': ['Documentary', 'Sport'],
#   'title': 'Over the Limit'},
#  '/release/rl1694795265/?ref_=bo_yld_table_933': {'domestic': 9512,
#   'international': None,
#   'worldwide': 9512,
#   'budget': None,
#   'genres': ['Biography', 'Documentary'],
#   'title': 'Living Proof'},
#  '/release/rl1845659137/?ref_=bo_yld_table_934': {'domestic': 55482,
#   'international': 725557,
#   'worldwide': 781039,
#   'budget': None,
#   'genres': ['Documentary'],
#   'title': 'The Paris Opera'},
#  '/release/rl1594131969/?ref_=bo_yld_table_935': {'domestic': 2784,
#   'international': None,
#   'worldwide': 2784,
#   'budget': None,
#   'genres': ['Documentary', 'History', 'War'],
#   'title': 'Nana'},
#  '/release/rl3540289025/?ref_=bo_yld_table_936': {'domestic': 2684,
#   'international': None,
#   'worldwide': 2684,
#   'budget': None,
#   'genres': ['Biography', 'Documentary', 'Music'],
#   'title': 'Straight Into a Storm'},
#  '/release/rl1845790209/?ref_=bo_yld_table_937': {'domestic': 2621,
#   'international': None,
#   'worldwide': 2621,
#   'budget': None,
#   'genres': ['Documentary'],
#   'title': 'ACORN and the Firestorm'},
#  '/release/rl1434224129/?ref_=bo_yld_table_938': {'domestic': 100234838,
#   'international': 310667824,
#   'worldwide': 410902662,
#   'budget': 104000000,
#   'genres': ['Action', 'Adventure', 'Comedy', 'Crime', 'Thriller'],
#   'title': 'Kingsman: The Golden Circle'},
#  '/release/rl688293377/?ref_=bo_yld_table_939': {'domestic': 2488,
#   'international': 1853159,
#   'worldwide': 1855647,
#   'budget': None,
#   'genres': ['Horror', 'Thriller'],
#   'title': 'The Pact'},
#  '/release/rl2751890945/?ref_=bo_yld_table_940': {'domestic': 3837,
#   'international': None,
#   'worldwide': 3837,
#   'budget': None,
#   'genres': ['Romance'],
#   'title': 'The Second Time Around'},
#  '/release/rl2952955393/?ref_=bo_yld_table_941': {'domestic': 15920,
#   'international': None,
#   'worldwide': 15920,
#   'budget': None,
#   'genres': ['Action', 'Adventure', 'Biography', 'Documentary'],
#   'title': 'Charged: The Eduardo Garcia Story'},
#  '/release/rl1359447553/?ref_=bo_yld_table_942': {'domestic': 2367,
#   'international': 60349,
#   'worldwide': 62716,
#   'budget': None,
#   'genres': ['Drama'],
#   'title': 'The Swan'},
#  '/release/rl755336705/?ref_=bo_yld_table_943': {'domestic': 13498,
#   'international': None,
#   'worldwide': 13498,
#   'budget': None,
#   'genres': ['Biography', 'Documentary'],
#   'title': 'Shadowman'},
#  '/release/rl1347585537/?ref_=bo_yld_table_944': {'domestic': 31502,
#   'international': None,
#   'worldwide': 31502,
#   'budget': None,
#   'genres': ['Documentary'],
#   'title': 'Forever'},
#  '/release/rl3775235585/?ref_=bo_yld_table_945': {'domestic': 2263,
#   'international': 65997,
#   'worldwide': 68260,
#   'budget': None,
#   'genres': ['Thriller'],
#   'title': '10x10'},
#  '/release/rl3204941313/?ref_=bo_yld_table_946': {'domestic': 2150,
#   'international': 5485111,
#   'worldwide': 5487261,
#   'budget': None,
#   'genres': ['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy'],
#   'title': "A Wizard's Tale"},
#  '/release/rl872580609/?ref_=bo_yld_table_947': {'domestic': 17778,
#   'international': None,
#   'worldwide': 17778,
#   'budget': None,
#   'genres': ['Documentary'],
#   'title': 'Escapes'},
#  '/release/rl2080736769/?ref_=bo_yld_table_948': {'domestic': 3392,
#   'international': None,
#   'worldwide': 3392,
#   'budget': None,
#   'genres': ['Action', 'Documentary', 'Drama'],
#   'title': 'The Cage Fighter'},
#  '/release/rl1392674305/?ref_=bo_yld_table_949': {'domestic': 12772,
#   'international': 12497,
#   'worldwide': 25269,
#   'budget': None,
#   'genres': ['Adventure', 'Drama', 'Romance'],
#   'title': 'In Search of Fellini'},
#  '/release/rl1443005953/?ref_=bo_yld_table_950': {'domestic': 31551,
#   'international': None,
#   'worldwide': 31551,
#   'budget': None,
#   'genres': ['Comedy', 'Drama', 'Romance'],
#   'title': 'Signature Move'},
#  '/release/rl1879279105/?ref_=bo_yld_table_951': {'domestic': 14637,
#   'international': None,
#   'worldwide': 14637,
#   'budget': None,
#   'genres': ['Documentary', 'War'],
#   'title': 'Last Men in Aleppo'},
#  '/release/rl1501464065/?ref_=bo_yld_table_952': {'domestic': 8540,
#   'international': None,
#   'worldwide': 8540,
#   'budget': None,
#   'genres': ['Documentary'],
#   'title': 'From the East'},
#  '/release/rl2969929217/?ref_=bo_yld_table_953': {'domestic': 1926,
#   'international': None,
#   'worldwide': 1926,
#   'budget': None,
#   'genres': ['Documentary'],
#   'title': 'West Of The Jordan River'},
#  '/release/rl1409517057/?ref_=bo_yld_table_954': {'domestic': 95952,
#   'international': 503585,
#   'worldwide': 599537,
#   'budget': None,
#   'genres': ['Biography', 'Drama', 'History', 'Sport'],
#   'title': 'The Fencer'},
#  '/release/rl2801960449/?ref_=bo_yld_table_955': {'domestic': 12847,
#   'international': None,
#   'worldwide': 12847,
#   'budget': None,
#   'genres': ['Comedy'],
#   'title': 'Permanent'},
#  '/release/rl1426359809/?ref_=bo_yld_table_956': {'domestic': 1841,
#   'international': None,
#   'worldwide': 1841,
#   'budget': None,
#   'genres': ['Documentary'],
#   'title': 'Finding Happiness'},
#  '/release/rl252020225/?ref_=bo_yld_table_957': {'domestic': 124187,
#   'international': 46139050,
#   'worldwide': 46263237,
#   'budget': None,
#   'genres': ['Action', 'Adventure', 'Fantasy'],
#   'title': 'The Thousand Faces of Dunjia'},
#  '/release/rl990283265/?ref_=bo_yld_table_958': {'domestic': 1780,
#   'international': None,
#   'worldwide': 1780,
#   'budget': None,
#   'genres': ['Documentary'],
#   'title': 'The Lost Village'},
#  '/release/rl889619969/?ref_=bo_yld_table_959': {'domestic': 1743,
#   'international': 4148,
#   'worldwide': 5891,
#   'budget': None,
#   'genres': ['Comedy'],
#   'title': 'An Actor Prepares'},
#  '/release/rl2936309249/?ref_=bo_yld_table_960': {'domestic': 4942,
#   'international': None,
#   'worldwide': 4942,
#   'budget': None,
#   'genres': ['Adventure', 'Comedy', 'Fantasy', 'Music', 'Romance', 'Western'],
#   'title': 'Tournament'},
#  '/release/rl2768668161/?ref_=bo_yld_table_961': {'domestic': 1447,
#   'international': None,
#   'worldwide': 1447,
#   'budget': None,
#   'genres': ['Documentary', 'Drama'],
#   'title': 'That Way Madness Lies...'},
#  '/release/rl1376028161/?ref_=bo_yld_table_962': {'domestic': 1377,
#   'international': 12293554,
#   'worldwide': 12294931,
#   'budget': None,
#   'genres': ['Drama', 'Horror', 'Mystery', 'Thriller'],
#   'title': 'Marrowbone'},
#  '/release/rl403080705/?ref_=bo_yld_table_963': {'domestic': 1368,
#   'international': None,
#   'worldwide': 1368,
#   'budget': None,
#   'genres': ['Comedy', 'Drama', 'Romance'],
#   'title': 'Beauty and the Beholder'},
#  '/release/rl1761838593/?ref_=bo_yld_table_964': {'domestic': 1017107,
#   'international': 75970,
#   'worldwide': 1093077,
#   'budget': None,
#   'genres': ['Drama'],
#   'title': 'Columbus'},
#  '/release/rl956728833/?ref_=bo_yld_table_965': {'domestic': 1359,
#   'international': 1619278,
#   'worldwide': 1620637,
#   'budget': None,
#   'genres': ['Fantasy', 'Horror', 'Sci-Fi', 'Thriller'],
#   'title': 'I Still See You'},
#  '/release/rl2701428225/?ref_=bo_yld_table_966': {'domestic': 19278,
#   'international': 11102,
#   'worldwide': 30380,
#   'budget': None,
#   'genres': ['Documentary'],
#   'title': 'Hare Krishna! The Mantra, the Movement and the Swami Who Started It'},
#  '/release/rl2684782081/?ref_=bo_yld_table_967': {'domestic': 1319,
#   'international': 1256618,
#   'worldwide': 1257937,
#   'budget': None,
#   'genres': ['Comedy', 'Drama', 'Music'],
#   'title': 'Guy'},
#  '/release/rl1258587649/?ref_=bo_yld_table_968': {'domestic': 1259,
#   'international': None,
#   'worldwide': 1259,
#   'budget': None,
#   'genres': ['Fantasy', 'Mystery', 'Sci-Fi', 'Thriller'],
#   'title': 'Altered Perception'},
#  '/release/rl4127491585/?ref_=bo_yld_table_969': {'domestic': 1227,
#   'international': None,
#   'worldwide': 1227,
#   'budget': None,
#   'genres': ['Comedy', 'Drama', 'War'],
#   'title': 'Two Men Went to War'},
#  '/release/rl2785314305/?ref_=bo_yld_table_970': {'domestic': 1190,
#   'international': None,
#   'worldwide': 1190,
#   'budget': None,
#   'genres': ['Documentary'],
#   'title': 'Under the Turban'},
#  '/release/rl1241941505/?ref_=bo_yld_table_971': {'domestic': 1469,
#   'international': None,
#   'worldwide': 1469,
#   'budget': None,
#   'genres': ['Animation', 'Comedy'],
#   'title': 'Henchmen'},
#  '/release/rl889357825/?ref_=bo_yld_table_972': {'domestic': 27151,
#   'international': None,
#   'worldwide': 27151,
#   'budget': None,
#   'genres': ['Documentary'],
#   'title': 'Bronx Gothic'},
#  '/release/rl2114356737/?ref_=bo_yld_table_973': {'domestic': 1034,
#   'international': None,
#   'worldwide': 1034,
#   'budget': None,
#   'genres': ['Documentary'],
#   'title': 'Invisible Hands'},
#  '/release/rl3993470465/?ref_=bo_yld_table_974': {'domestic': 954,
#   'international': 2696568,
#   'worldwide': 2697522,
#   'budget': None,
#   'genres': ['Action', 'Adventure', 'Comedy', 'Crime'],
#   'title': 'Gangsterdam'},
#  '/release/rl2265155073/?ref_=bo_yld_table_975': {'domestic': 27739,
#   'international': None,
#   'worldwide': 27739,
#   'budget': None,
#   'genres': ['Documentary'],
#   'title': '30 Years of Garbage: The Garbage Pail Kids Story'},
#  '/release/rl2718205441/?ref_=bo_yld_table_976': {'domestic': 19499,
#   'international': None,
#   'worldwide': 19499,
#   'budget': None,
#   'genres': ['Documentary'],
#   'title': 'BOSTON: An American Running Story'},
#  '/release/rl2281866753/?ref_=bo_yld_table_977': {'domestic': 5088,
#   'international': None,
#   'worldwide': 5088,
#   'budget': None,
#   'genres': ['Comedy', 'Drama'],
#   'title': 'Bad Lucky Goat'},
#  '/release/rl1124369921/?ref_=bo_yld_table_978': {'domestic': 834,
#   'international': 2426073,
#   'worldwide': 2426907,
#   'budget': None,
#   'genres': ['Animation', 'Drama', 'Family', 'War'],
#   'title': 'The Breadwinner'},
#  '/release/rl1728349697/?ref_=bo_yld_table_979': {'domestic': 16533,
#   'international': None,
#   'worldwide': 16533,
#   'budget': None,
#   'genres': ['Documentary'],
#   'title': '33 & Beyond: The Royal Art of Freemasonry'},
#  '/release/rl1007060481/?ref_=bo_yld_table_980': {'domestic': 812,
#   'international': None,
#   'worldwide': 812,
#   'budget': None,
#   'genres': ['Documentary'],
#   'title': 'TVTV: Video Revolutionaries'},
#  '/release/rl3976300033/?ref_=bo_yld_table_981': {'domestic': 3000,
#   'international': None,
#   'worldwide': 3000,
#   'budget': None,
#   'genres': ['Horror', 'Thriller'],
#   'title': 'The Ghosts of Johnson Woods'},
#  '/release/rl526288385/?ref_=bo_yld_table_982': {'domestic': 55038,
#   'international': None,
#   'worldwide': 55038,
#   'budget': None,
#   'genres': ['Documentary'],
#   'title': 'The Lovely Month of May'},
#  '/release/rl3245639169/?ref_=bo_yld_table_983': {'domestic': 5129,
#   'international': None,
#   'worldwide': 5129,
#   'budget': None,
#   'genres': ['Action', 'Comedy'],
#   'title': 'To Die Is Hard'},
#  '/release/rl2013562369/?ref_=bo_yld_table_984': {'domestic': 528,
#   'international': None,
#   'worldwide': 528,
#   'budget': None,
#   'genres': ['Action', 'Sci-Fi', 'Thriller'],
#   'title': 'Higher Power'},
#  '/release/rl2405926401/?ref_=bo_yld_table_985': {'domestic': 163962,
#   'international': 13672,
#   'worldwide': 177634,
#   'budget': None,
#   'genres': ['Documentary'],
#   'title': 'Nostalgia for the Light'},
#  '/release/rl486966785/?ref_=bo_yld_table_986': {'domestic': 451,
#   'international': 53287,
#   'worldwide': 53738,
#   'budget': None,
#   'genres': ['Adventure', 'Animation', 'Family', 'Fantasy'],
#   'title': 'The Legend of Hallowaiian'},
#  '/release/rl2976024065/?ref_=bo_yld_table_987': {'domestic': 11006,
#   'international': None,
#   'worldwide': 11006,
#   'budget': 2000,
#   'genres': ['Comedy', 'Horror'],
#   'title': 'Midget Zombie Takeover'},
#  '/release/rl1409451521/?ref_=bo_yld_table_988': {'domestic': 35195,
#   'international': None,
#   'worldwide': 35195,
#   'budget': None,
#   'genres': ['Documentary'],
#   'title': 'Rat Film'},
#  '/release/rl1695057409/?ref_=bo_yld_table_989': {'domestic': 10389,
#   'international': 1179,
#   'worldwide': 11568,
#   'budget': None,
#   'genres': ['Documentary'],
#   'title': 'Around India with a Movie Camera'},
#  '/release/rl3574040065/?ref_=bo_yld_table_990': {'domestic': 8132,
#   'international': None,
#   'worldwide': 8132,
#   'budget': None,
#   'genres': ['Documentary', 'Drama', 'War'],
#   'title': 'Far from Vietnam'},
#  '/release/rl242714113/?ref_=bo_yld_table_991': {'domestic': 18236,
#   'international': None,
#   'worldwide': 18236,
#   'budget': None,
#   'genres': ['Documentary', 'Music'],
#   'title': "Tosca's Kiss"},
#  '/release/rl1400669697/?ref_=bo_yld_table_992': {'domestic': 6201,
#   'international': None,
#   'worldwide': 6201,
#   'budget': None,
#   'genres': ['Documentary'],
#   'title': 'A Man Vanishes'},
#  '/release/rl2668070401/?ref_=bo_yld_table_993': {'domestic': 147,
#   'international': 22296,
#   'worldwide': 22443,
#   'budget': None,
#   'genres': ['Horror', 'Mystery'],
#   'title': 'Realms'}}

# %%
bom_df_dict= {}
for year in range(1977,2021):
    bom_df_dict[year] = pd.DataFrame.from_dict(movie_dict[year],orient="index")
    bom_df_dict[year].to_csv("zippedData/bom-budget-and-genres-{}.csv".format(year))
